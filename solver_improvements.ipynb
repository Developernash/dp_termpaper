# %% [markdown]
# # analysis for improving the solver

# %% [markdown]
# Asking the question Does numerical approximation of the dynamic problem matter?
# Could be answered by using finer grids in the model_config space as seen below

# %%
"assets_end_of_period": jnp.linspace(0.0, 50.0, 100)
"experience": jnp.linspace(0.0, 1.0, 15)
"n_quad_points": 9

# %% [markdown]
# Asking the question: does monte carlo noise matter?
# Could be answered by running different simulation sizes and inspect the differences

# %%
simulation_sizes = [10_000, 25_000, 50_000, 100_000]
