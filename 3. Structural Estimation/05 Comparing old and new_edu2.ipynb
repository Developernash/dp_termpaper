# %% [markdown]
# # Comparing the Criterion Value
# ## Original Model vs Phi Specified Model
# ### Education Level 2

# %% [markdown]
# ## Dependencies, Packages & Roots

# %% [markdown]
# ### Magics

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Project Paths

# %%
from pathlib import Path
import sys
import importlib

# Change this depending on notebook location:
# 0 = notebook is 1 folder inside project root, e.g. dp_termpaper/edu1
# 1 = notebook is 2 folders inside project root, e.g. dp_termpaper/data/moments
# 2 = notebook is 3 folders inside project root
amount_of_levels = 0

DIR = Path.cwd().resolve().parents[amount_of_levels]

if str(DIR) not in sys.path:
    sys.path.insert(0, str(DIR))

import project_paths as pp
from project_imports import *

importlib.reload(pp)
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Load Data

# %%
###############################################################
#### Define which education level you want to estimate for ####
###############################################################

# education_level_file = pp.MOMENTS_DIR / "moments_udd1.txt"
education_level_file = pp.MOMENTS_DIR / "moments_udd2.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd3.txt"

version = "phi_edu2" # for saving results, change this when you change the specification

MORTALITY = pp.DATA_DIR / "mortality.xlsx"

beta0, beta1, beta2 = np.loadtxt(pp.FIRST_STAGE_RESULTS_DIR / "wage_params_udd2_ols.txt")

# %%
# Read CSV
df_edu = pd.read_csv(education_level_file)
# read mortality and discard seoncd and third column
df_mort = pd.read_excel(MORTALITY, sheet_name="DOD", usecols=[0, 3])

# 2) standardize colomn name and remove _FREQ_ column
# Iterate over DataFrames (if there are multiple DataFrames to process)
for data_frame in [df_edu]:
    # Rename ALDER → age
    if "ALDER" in data_frame.columns:
        data_frame.rename(columns={"ALDER": "age"}, inplace=True)
    # Remove _FREQ_-column if it exists
    # if "_FREQ_" in data_frame.columns:
    #     data_frame.drop(columns=["_FREQ_"], inplace=True)
# drop var_wage, skew_wage and pens
df_edu.drop(columns=["var_wage", "skew_wage", "pens"], inplace=True)
# df_edu

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
labour_choices = np.arange(5) # 5 choices
alpha1, alpha2 = np.loadtxt(pp.STRUCTURAL_RESULTS_DIR/ "mortality_params.txt")

model_config = {
    "n_periods": n_periods,
    "choices": labour_choices, # 5 choices
    "n_quad_points": 5,
    "continuous_states": {
        "assets_end_of_period": np.linspace(0, 50, 20),
        "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
    "stochastic_states": {
        "survival": [0, 1],
    }
    }

model_specs = {
    "choices": labour_choices, # 5 choices
    "n_periods": n_periods,
    "labour_choices": labour_choices, # 5 choices
    "hours": jnp.array([0,250,750,1300,1900]), #list 
    "max_hours": 1900,
    "start_age": 30,
    "tax_threshold1": 0.480,
    "tax_threshold2": 5.698,
    "tax_base_rate": 0.38,
    "tax_top_rate": 0.5,
    "retirement_age": 67,
    "oap_base_amount": 0.80328,
    "oap_max_supplement": 0.92940,
    "supp_threshold": 0.79300,
    "oap_threshold": 3.3592,
    "supp_reduction_rate": 0.309,
    "oap_reduction_rate": 0.3,
    "alpha1": alpha1, # independently estimated parameter for survival probability
    "alpha2": alpha2,  # independently estimated parameter for survival probability
    "max_init_experience": 5,
    "max_ret_period": 45, # Age 75
    "min_ret_period": 30, # Age 60
}
stochastic_states_transitions = {
    "survival": prob_survival
}

# %% [markdown]
# ### Initial values for simulating.

# %%
# Select number of individuals for simulation
#Debug level
n_individuals = 10000

# Optimal level
# n_individuals = 250000

seed = 132
key = jax.random.PRNGKey(0)
n = n_individuals       

# hours mapping for simulation
hours_map = {0: 0, 1: 250, 2: 750, 3: 1300, 4: 1900}

#age for simulation
start_age = model_specs["start_age"] 

# distribution of initial choices
labels = jnp.array([0, 1, 2, 3, 4], dtype=jnp.int32)
probs  = jnp.array([0.259155, 0.118310, 0.108099, 0.108451, 0.405986])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)

# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals, dtype=jnp.int32),      # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 1).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals, dtype=jnp.int32), # Every individual starts with 1 (alive)
    "assets_begin_of_period": jnp.full(n_individuals, 0.505047) # Every individual starts with 59k wealth - to be adjusted based on the actual moments
}

# %% [markdown]
# ### Define Criterion function for simulating across seeds

# %%
def criterion(model_solved, seed=seed):
    
    keep_cols = ["hours_0", "hours_1","hours_2","hours_3","hours_4", "work_work", "nowork_nowork"]

    # Simulate model
    sim = model_solved.simulate(
        states_initial=states_initial,
        seed=seed,
    )

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(sim, start_age, hours_map)
    empirical_moms = df_edu.copy()  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]

    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    print("Simulated moments shape:", sim_vals.shape)
    print("Empirical moments shape:", emp_vals.shape)

    # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-10

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Seed:", seed)
    print("Crit value:", crit_val)
    return float(crit_val)

# %% [markdown]
# ## New model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params = load_params_txt(pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_phi_udd2.txt")
params["gamma"] = jnp.asarray(params["gamma"])

# %%
new_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
new_model_solved = new_model.solve(params)
new_model.validate_exogenous(params)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for my model

# %%
new_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(new_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    new_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })


new_model_crit_table = pd.DataFrame(new_model_results)

new_model_crit_table

new_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "new_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 346856325
# Crit value: 168.89586417766293
# Run 001 | Seed: 346856325 | Criterion value: 168.895864
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1192886315
# Crit value: 173.17748360687764
# Run 002 | Seed: 1192886315 | Criterion value: 173.177484
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1428749856
# Crit value: 177.0284056108852
# Run 003 | Seed: 1428749856 | Criterion value: 177.028406
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1273069391
# Crit value: 173.83109031608734
# Run 004 | Seed: 1273069391 | Criterion value: 173.831090
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 691081003
# Crit value: 176.18591605740446
# Run 005 | Seed: 691081003 | Criterion value: 176.185916
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2117291235
# Crit value: 171.0871136609617
# Run 006 | Seed: 2117291235 | Criterion value: 171.087114
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1425930485
# Crit value: 173.2809412919895
# Run 007 | Seed: 1425930485 | Criterion value: 173.280941
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 132847401
# Crit value: 172.54104621470682
# Run 008 | Seed: 132847401 | Criterion value: 172.541046
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1321320445
# Crit value: 175.50345311633473
# Run 009 | Seed: 1321320445 | Criterion value: 175.503453
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 498324003
# Crit value: 174.72701408292022
# Run 010 | Seed: 498324003 | Criterion value: 174.727014
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 658513439
# Crit value: 171.43302873426327
# Run 011 | Seed: 658513439 | Criterion value: 171.433029
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1839244414
# Crit value: 168.99831344750177
# Run 012 | Seed: 1839244414 | Criterion value: 168.998313
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1584486661
# Crit value: 169.57970911011753
# Run 013 | Seed: 1584486661 | Criterion value: 169.579709
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 242350311
# Crit value: 168.40680588027215
# Run 014 | Seed: 242350311 | Criterion value: 168.406806
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1287015213
# Crit value: 176.25739491739628
# Run 015 | Seed: 1287015213 | Criterion value: 176.257395
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1851584970
# Crit value: 169.39029799904168
# Run 016 | Seed: 1851584970 | Criterion value: 169.390298
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1011322992
# Crit value: 167.38519377179864
# Run 017 | Seed: 1011322992 | Criterion value: 167.385194
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1518351482
# Crit value: 171.9643148022276
# Run 018 | Seed: 1518351482 | Criterion value: 171.964315
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1312309968
# Crit value: 172.7213809286406
# Run 019 | Seed: 1312309968 | Criterion value: 172.721381
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 136412903
# Crit value: 171.879796373667
# Run 083 | Seed: 136412903 | Criterion value: 171.879796
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1456899553
# Crit value: 174.3218337809793
# Run 084 | Seed: 1456899553 | Criterion value: 174.321834
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 165597253
# Crit value: 171.97028233993328
# Run 085 | Seed: 165597253 | Criterion value: 171.970282
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1204498801
# Crit value: 173.39431961716343
# Run 086 | Seed: 1204498801 | Criterion value: 173.394320
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2081975458
# Crit value: 169.53223811107708
# Run 087 | Seed: 2081975458 | Criterion value: 169.532238
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 322650186
# Crit value: 172.27233705594125
# Run 088 | Seed: 322650186 | Criterion value: 172.272337
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1428209215
# Crit value: 166.98584927816347
# Run 089 | Seed: 1428209215 | Criterion value: 166.985849
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 582354811
# Crit value: 175.88272598582952
# Run 090 | Seed: 582354811 | Criterion value: 175.882726
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2019442772
# Crit value: 177.39812941631777
# Run 091 | Seed: 2019442772 | Criterion value: 177.398129
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1352019255
# Crit value: 169.01121564574936
# Run 092 | Seed: 1352019255 | Criterion value: 169.011216
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1431347713
# Crit value: 171.43774622371726
# Run 093 | Seed: 1431347713 | Criterion value: 171.437746
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1991002848
# Crit value: 178.2342025242366
# Run 094 | Seed: 1991002848 | Criterion value: 178.234203
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1975221598
# Crit value: 166.95280485181988
# Run 095 | Seed: 1975221598 | Criterion value: 166.952805
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 473796595
# Crit value: 170.20200841075643
# Run 096 | Seed: 473796595 | Criterion value: 170.202008
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 245967099
# Crit value: 173.36291635417265
# Run 097 | Seed: 245967099 | Criterion value: 173.362916
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1684717315
# Crit value: 168.81863122519184
# Run 098 | Seed: 1684717315 | Criterion value: 168.818631
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1646627059
# Crit value: 170.7297596463003
# Run 099 | Seed: 1646627059 | Criterion value: 170.729760
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1303599334
# Crit value: 167.86089239269037
# Run 100 | Seed: 1303599334 | Criterion value: 167.860892

# %% [markdown]
# ## Old model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params_old = {
"interest_rate": 0.01,
"income_shock_mean": 0.0,
"income_shock_std": 0.336434797,
"taste_shock_scale": 1.53893135,
"discount_factor": 0.983346704,
"rho": 0.4549787,
"gamma": jnp.asarray([0.74983436, 1.45028143, 1.89887675, 1.695886]),
"kappa1": 0.0232678405,
"kappa2": 0.000640643531,
"phi": 2.94930837,
"b_scale": 0.821471016,
"xi": 0.338026425,
"eta_edu": 0.69164,
"alpha1": 0.000417,
"alpha2": 0.099277,
"beta0": -7.345297182291485,
"beta1": 0.05220790715541536,
"beta2": -0.00039990127757635316
}

# %%
def flow_util(consumption, choice, params, period, model_specs, lagged_choice):
    # Utility parameter
    rho = params["rho"]

    # Disutility parameters
    age = (model_specs["start_age"] + period).astype(float)
    gamma = params["gamma"][choice - 1]  # remove the first element

    ##############################################
    ########## Disutility of working #############
    ##############################################
    working = choice > 0  # 1 if choice is working, 0 if not
    # -------  Zero disutility from working if unemployed

    # Age component of disutility
    age_linear = jnp.where(age >= 55, params["kappa1"] * (age - 55), 0.0)
    age_quadratic = jnp.where(age >= 55, params["kappa2"] * (age - 55) ** 2, 0.0)   
    # + age_linear

    # estimate total disutility
    disutil_0 = working * (1.0 + age_linear + age_quadratic) * gamma

    # No disutility from working, if you dont work.
    disutil = jnp.where(working, disutil_0, 0.0)  # if working == 0, disutility = 0

    ##############################################
    ############# Transaction costs  #############
    ##############################################

    # transition cost when going from working to unemployed, and vice versa
    trans_cost = jnp.where(
        choice != lagged_choice, params["phi"], 0.0
    )

    # Utility for agents that are alive.
    u = (
        ((consumption ** (1 - rho)) - 1) / (1 - rho) - disutil - trans_cost
    ) 

    return u


def marginal_utility(consumption, params):
    rho = params["rho"]
    u_prime = consumption ** (-rho)
    return u_prime


def inverse_marginal_utility(marginal_utility, params):
    rho = params["rho"]
    return marginal_utility ** (-1 / rho)


utility_functions = {
    "utility": flow_util,
    "inverse_marginal_utility": inverse_marginal_utility,
    "marginal_utility": marginal_utility,
}

# %%
old_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
old_model_solved = old_model.solve(params_old)
old_model.validate_exogenous(params_old)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for Larsen model

# %%
old_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(old_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    old_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })

old_model_crit_table = pd.DataFrame(old_model_results)

old_model_crit_table

old_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "old_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 48823603
# Crit value: 242.38159053527986
# Run 001 | Seed: 48823603 | Criterion value: 242.381591
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1709674370
# Crit value: 241.0705222864814
# Run 002 | Seed: 1709674370 | Criterion value: 241.070522
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 355855818
# Crit value: 236.33051642914538
# Run 003 | Seed: 355855818 | Criterion value: 236.330516
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 899521276
# Crit value: 242.07726670281173
# Run 004 | Seed: 899521276 | Criterion value: 242.077267
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 802162697
# Crit value: 244.09411001061395
# Run 005 | Seed: 802162697 | Criterion value: 244.094110
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 217453266
# Crit value: 240.1504194301153
# Run 006 | Seed: 217453266 | Criterion value: 240.150419
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 279913755
# Crit value: 247.79388091778597
# Run 007 | Seed: 279913755 | Criterion value: 247.793881
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 610986471
# Crit value: 243.37991281767418
# Run 008 | Seed: 610986471 | Criterion value: 243.379913
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 469293585
# Crit value: 233.96319154117919
# Run 009 | Seed: 469293585 | Criterion value: 233.963192
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 480219740
# Crit value: 238.19200291707705
# Run 010 | Seed: 480219740 | Criterion value: 238.192003
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 350487646
# Crit value: 235.28970719700604
# Run 011 | Seed: 350487646 | Criterion value: 235.289707
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1597545343
# Crit value: 234.71611069729767
# Run 012 | Seed: 1597545343 | Criterion value: 234.716111
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2081284409
# Crit value: 242.7294074289308
# Run 013 | Seed: 2081284409 | Criterion value: 242.729407
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1882280250
# Crit value: 233.99317357079548
# Run 014 | Seed: 1882280250 | Criterion value: 233.993174
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2078628641
# Crit value: 230.9467509737221
# Run 015 | Seed: 2078628641 | Criterion value: 230.946751
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1144360346
# Crit value: 242.33003084446693
# Run 016 | Seed: 1144360346 | Criterion value: 242.330031
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 165315820
# Crit value: 229.9447292709672
# Run 017 | Seed: 165315820 | Criterion value: 229.944729
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 211267907
# Crit value: 237.06920877946033
# Run 018 | Seed: 211267907 | Criterion value: 237.069209
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2049891042
# Crit value: 238.5396632905078
# Run 019 | Seed: 2049891042 | Criterion value: 238.539663
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1344352748
# Crit value: 236.40552702134332
# Run 020 | Seed: 1344352748 | Criterion value: 236.405527
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 717251505
# Crit value: 236.49045340645503
# Run 021 | Seed: 717251505 | Criterion value: 236.490453
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1904456608
# Crit value: 238.07262901620643
# Run 053 | Seed: 1904456608 | Criterion value: 238.072629
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 872030689
# Crit value: 238.12445895585134
# Run 054 | Seed: 872030689 | Criterion value: 238.124459
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1401965206
# Crit value: 234.9202886917084
# Run 055 | Seed: 1401965206 | Criterion value: 234.920289
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 449274394
# Crit value: 235.03687444125694
# Run 056 | Seed: 449274394 | Criterion value: 235.036874
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1867091158
# Crit value: 245.10665080901006
# Run 057 | Seed: 1867091158 | Criterion value: 245.106651
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2077275297
# Crit value: 241.55330056388166
# Run 058 | Seed: 2077275297 | Criterion value: 241.553301
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1690018013
# Crit value: 235.60876774730346
# Run 059 | Seed: 1690018013 | Criterion value: 235.608768
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2012811446
# Crit value: 244.97147039557498
# Run 060 | Seed: 2012811446 | Criterion value: 244.971470
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 931728164
# Crit value: 240.51009920654587
# Run 061 | Seed: 931728164 | Criterion value: 240.510099
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1265025075
# Crit value: 235.848484473112
# Run 062 | Seed: 1265025075 | Criterion value: 235.848484
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2081152056
# Crit value: 238.95668075561457
# Run 063 | Seed: 2081152056 | Criterion value: 238.956681
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 760861665
# Crit value: 238.82367017512505
# Run 064 | Seed: 760861665 | Criterion value: 238.823670
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2118886819
# Crit value: 244.30151092557395
# Run 065 | Seed: 2118886819 | Criterion value: 244.301511
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1135233328
# Crit value: 230.19850307045422
# Run 066 | Seed: 1135233328 | Criterion value: 230.198503
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1510397675
# Crit value: 236.98644783701633
# Run 067 | Seed: 1510397675 | Criterion value: 236.986448
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1624838582
# Crit value: 232.89405960155653
# Run 068 | Seed: 1624838582 | Criterion value: 232.894060
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2076520241
# Crit value: 236.72476778395782
# Run 069 | Seed: 2076520241 | Criterion value: 236.724768
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 987410202
# Crit value: 238.8647685476435
# Run 070 | Seed: 987410202 | Criterion value: 238.864769
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 683963068
# Crit value: 235.2541304401997
# Run 071 | Seed: 683963068 | Criterion value: 235.254130
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 800420056
# Crit value: 240.0335775091552
# Run 072 | Seed: 800420056 | Criterion value: 240.033578
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 472413476
# Crit value: 242.36746625185356
# Run 073 | Seed: 472413476 | Criterion value: 242.367466
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1797750192
# Crit value: 236.9525299156574
# Run 074 | Seed: 1797750192 | Criterion value: 236.952530
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 712993290
# Crit value: 227.80995831567995
# Run 075 | Seed: 712993290 | Criterion value: 227.809958
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1109897243
# Crit value: 246.30376660566517
# Run 076 | Seed: 1109897243 | Criterion value: 246.303767
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 682112794
# Crit value: 238.71035297958383
# Run 077 | Seed: 682112794 | Criterion value: 238.710353
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2073895700
# Crit value: 234.86062621766214
# Run 078 | Seed: 2073895700 | Criterion value: 234.860626
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 963754030
# Crit value: 240.53766485743208
# Run 079 | Seed: 963754030 | Criterion value: 240.537665
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 86107214
# Crit value: 247.19319029317217
# Run 080 | Seed: 86107214 | Criterion value: 247.193190
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 114275028
# Crit value: 245.66632280061648
# Run 081 | Seed: 114275028 | Criterion value: 245.666323
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 281694678
# Crit value: 244.13982385283256
# Run 082 | Seed: 281694678 | Criterion value: 244.139824
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 517589024
# Crit value: 248.1114254754415
# Run 083 | Seed: 517589024 | Criterion value: 248.111425
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 288892089
# Crit value: 241.02282148027976
# Run 084 | Seed: 288892089 | Criterion value: 241.022821
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1700477359
# Crit value: 240.36571068570683
# Run 085 | Seed: 1700477359 | Criterion value: 240.365711
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 426343499
# Crit value: 244.82125208773604
# Run 086 | Seed: 426343499 | Criterion value: 244.821252
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 286112436
# Crit value: 238.42838401797616
# Run 087 | Seed: 286112436 | Criterion value: 238.428384
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1391673864
# Crit value: 239.15845854835496
# Run 088 | Seed: 1391673864 | Criterion value: 239.158459
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1367077488
# Crit value: 241.49630377579155
# Run 089 | Seed: 1367077488 | Criterion value: 241.496304
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1532925777
# Crit value: 244.15769438560514
# Run 090 | Seed: 1532925777 | Criterion value: 244.157694
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 914332062
# Crit value: 236.91836285877963
# Run 091 | Seed: 914332062 | Criterion value: 236.918363
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 304919742
# Crit value: 236.34211037108923
# Run 092 | Seed: 304919742 | Criterion value: 236.342110
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1637864351
# Crit value: 235.45257607439237
# Run 093 | Seed: 1637864351 | Criterion value: 235.452576
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2087950664
# Crit value: 245.40144602158378
# Run 094 | Seed: 2087950664 | Criterion value: 245.401446
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1871829815
# Crit value: 238.92449448542766
# Run 095 | Seed: 1871829815 | Criterion value: 238.924494
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 643964181
# Crit value: 235.38086518415213
# Run 096 | Seed: 643964181 | Criterion value: 235.380865
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 360145398
# Crit value: 235.86936994683205
# Run 097 | Seed: 360145398 | Criterion value: 235.869370
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 495268152
# Crit value: 244.8593294264365
# Run 098 | Seed: 495268152 | Criterion value: 244.859329
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 542204690
# Crit value: 228.80266781603623
# Run 099 | Seed: 542204690 | Criterion value: 228.802668
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2000040369
# Crit value: 245.96680959897685
# Run 100 | Seed: 2000040369 | Criterion value: 245.966810

# %% [markdown]
# ### Plot the results from both runs

# %%
import matplotlib.pyplot as plt
import pandas as pd

old_vals = old_model_crit_table["criterion_value"]
new_vals = new_model_crit_table["criterion_value"]

summary_table = pd.DataFrame({
    "model": ["old", "new"],
    "mean": [old_vals.mean(), new_vals.mean()],
    "median": [old_vals.median(), new_vals.median()],
    "std": [old_vals.std(), new_vals.std()],
    "min": [old_vals.min(), new_vals.min()],
    "max": [old_vals.max(), new_vals.max()],
})

summary_table
# Out:
#   model        mean      median       std         min         max
# 0   old  239.285366  238.894632  4.508924  227.809958  248.111425
# 1   new  171.419784  171.367991  3.349316  162.964981  178.974624

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    old_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="Old model",
)

plt.hist(
    new_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="New model",
)

plt.axvline(old_vals.mean(), linestyle="--", label=f"Old mean: {old_vals.mean():.2f}")
plt.axvline(new_vals.mean(), linestyle="--", label=f"New mean: {new_vals.mean():.2f}")

plt.xlabel("Criterion value")
plt.ylabel("Density")
plt.title("Distribution of Criterion Values Across Seeds")
plt.legend()
plt.tight_layout()
plt.show()

# %%
crit_compare = pd.concat(
    [
        old_model_crit_table.assign(model="Old model"),
        new_model_crit_table.assign(model="New model"),
    ],
    ignore_index=True,
)

plt.figure(figsize=(7, 5))

crit_compare.boxplot(
    column="criterion_value",
    by="model",
    grid=False,
)

plt.title("Criterion Value by Model")
plt.suptitle("")
plt.xlabel("")
plt.ylabel("Criterion value")
plt.tight_layout()
plt.show()
