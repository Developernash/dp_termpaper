# %% [markdown]
# # Comparing the Criterion Value
# ## Original Model vs Phi Specified Model
# ### Education Level 3

# %% [markdown]
# ## Dependencies, Packages & Roots

# %% [markdown]
# ### Magics

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Project Paths

# %%
from pathlib import Path
import sys
import importlib

# Change this depending on notebook location:
# 0 = notebook is 1 folder inside project root, e.g. dp_termpaper/edu1
# 1 = notebook is 2 folders inside project root, e.g. dp_termpaper/data/moments
# 2 = notebook is 3 folders inside project root
amount_of_levels = 0

DIR = Path.cwd().resolve().parents[amount_of_levels]

if str(DIR) not in sys.path:
    sys.path.insert(0, str(DIR))

import project_paths as pp
from project_imports import *

importlib.reload(pp)
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Load Data

# %%
###############################################################
#### Define which education level you want to estimate for ####
###############################################################

# education_level_file = pp.MOMENTS_DIR / "moments_udd1.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd2.txt"
education_level_file = pp.MOMENTS_DIR / "moments_udd3.txt"

version = "phi_udd3" # for saving results, change this when you change the specification

MORTALITY = pp.DATA_DIR / "mortality.xlsx"

beta0, beta1, beta2 = np.loadtxt(pp.FIRST_STAGE_RESULTS_DIR / "wage_params_udd3_ols.txt")

# %%
# Read CSV
df_edu = pd.read_csv(education_level_file)
# read mortality and discard seoncd and third column
df_mort = pd.read_excel(MORTALITY, sheet_name="DOD", usecols=[0, 3])

# 2) standardize colomn name and remove _FREQ_ column
# Iterate over DataFrames (if there are multiple DataFrames to process)
for data_frame in [df_edu]:
    # Rename ALDER → age
    if "ALDER" in data_frame.columns:
        data_frame.rename(columns={"ALDER": "age"}, inplace=True)
    # Remove _FREQ_-column if it exists
    # if "_FREQ_" in data_frame.columns:
    #     data_frame.drop(columns=["_FREQ_"], inplace=True)
# drop var_wage, skew_wage and pens
df_edu.drop(columns=["var_wage", "skew_wage", "pens"], inplace=True)
# df_edu

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
labour_choices = np.arange(5) # 5 choices
alpha1, alpha2 = np.loadtxt(pp.STRUCTURAL_RESULTS_DIR/ "mortality_params.txt")

model_config = {
    "n_periods": n_periods,
    "choices": labour_choices, # 5 choices
    "n_quad_points": 5,
    "continuous_states": {
        "assets_end_of_period": np.linspace(0, 50, 20),
        "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
    "stochastic_states": {
        "survival": [0, 1],
    }
    }

model_specs = {
    "choices": labour_choices, # 5 choices
    "n_periods": n_periods,
    "labour_choices": labour_choices, # 5 choices
    "hours": jnp.array([0,250,750,1300,1900]), #list 
    "max_hours": 1900,
    "start_age": 30,
    "tax_threshold1": 0.480,
    "tax_threshold2": 5.698,
    "tax_base_rate": 0.38,
    "tax_top_rate": 0.5,
    "retirement_age": 67,
    "oap_base_amount": 0.80328,
    "oap_max_supplement": 0.92940,
    "supp_threshold": 0.79300,
    "oap_threshold": 3.3592,
    "supp_reduction_rate": 0.309,
    "oap_reduction_rate": 0.3,
    "alpha1": alpha1, # independently estimated parameter for survival probability
    "alpha2": alpha2,  # independently estimated parameter for survival probability
    "max_init_experience": 5,
    "max_ret_period": 45, # Age 75
    "min_ret_period": 30, # Age 60
}
stochastic_states_transitions = {
    "survival": prob_survival
}

# %% [markdown]
# ### Initial values for simulating.

# %%
# Select number of individuals for simulation
#Debug level
n_individuals = 10000

# Optimal level
# n_individuals = 250000

seed = 132
key = jax.random.PRNGKey(0)
n = n_individuals       

# hours mapping for simulation
hours_map = {0: 0, 1: 250, 2: 750, 3: 1300, 4: 1900}

#age for simulation
start_age = model_specs["start_age"] 

# distribution of initial choices
labels = jnp.array([0, 1, 2, 3, 4], dtype=jnp.int32)
probs  = jnp.array([0.259155, 0.118310, 0.108099, 0.108451, 0.405986])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)

# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals, dtype=jnp.int32),      # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 1).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals, dtype=jnp.int32), # Every individual starts with 1 (alive)
    "assets_begin_of_period": jnp.full(n_individuals, 0.505047) # Every individual starts with 59k wealth - to be adjusted based on the actual moments
}

# %% [markdown]
# ### Define Criterion function for simulating across seeds

# %%
def criterion(model_solved, seed=seed):
    
    keep_cols = ["hours_0", "hours_1","hours_2","hours_3","hours_4", "work_work", "nowork_nowork"]

    # Simulate model
    sim = model_solved.simulate(
        states_initial=states_initial,
        seed=seed,
    )

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(sim, start_age, hours_map)
    empirical_moms = df_edu.copy()  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]

    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    print("Simulated moments shape:", sim_vals.shape)
    print("Empirical moments shape:", emp_vals.shape)

    # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-10

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Seed:", seed)
    print("Crit value:", crit_val)
    return float(crit_val)

# %% [markdown]
# ## New model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params = load_params_txt(pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_phi_udd3.txt")
params["gamma"] = jnp.asarray(params["gamma"])

# %%
new_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
new_model_solved = new_model.solve(params)
new_model.validate_exogenous(params)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for my model

# %%
new_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(new_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    new_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })


new_model_crit_table = pd.DataFrame(new_model_results)

new_model_crit_table

new_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "new_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 41741658
# Crit value: 204.4579604792205
# Run 001 | Seed: 41741658 | Criterion value: 204.457960
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 837661803
# Crit value: 219.41689593536114
# Run 002 | Seed: 837661803 | Criterion value: 219.416896
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2028058841
# Crit value: 201.99168794649273
# Run 003 | Seed: 2028058841 | Criterion value: 201.991688
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 30240261
# Crit value: 212.87039197024313
# Run 004 | Seed: 30240261 | Criterion value: 212.870392
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 5992018
# Crit value: 214.54853087660345
# Run 005 | Seed: 5992018 | Criterion value: 214.548531
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 698040508
# Crit value: 227.4930163420896
# Run 006 | Seed: 698040508 | Criterion value: 227.493016
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 745107628
# Crit value: 216.69922593814766
# Run 007 | Seed: 745107628 | Criterion value: 216.699226
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1963374207
# Crit value: 208.50388135785502
# Run 008 | Seed: 1963374207 | Criterion value: 208.503881
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1945815864
# Crit value: 210.49345986435162
# Run 009 | Seed: 1945815864 | Criterion value: 210.493460
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 924659447
# Crit value: 213.8153144330792
# Run 010 | Seed: 924659447 | Criterion value: 213.815314
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1037827067
# Crit value: 212.84985543523982
# Run 011 | Seed: 1037827067 | Criterion value: 212.849855
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1403233708
# Crit value: 206.3491468801012
# Run 012 | Seed: 1403233708 | Criterion value: 206.349147
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 759964433
# Crit value: 220.30638573361847
# Run 013 | Seed: 759964433 | Criterion value: 220.306386
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 991106715
# Crit value: 199.27688388561728
# Run 014 | Seed: 991106715 | Criterion value: 199.276884
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1809113180
# Crit value: 216.3649925339357
# Run 015 | Seed: 1809113180 | Criterion value: 216.364993
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 833029614
# Crit value: 215.757504295748
# Run 016 | Seed: 833029614 | Criterion value: 215.757504
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1751428241
# Crit value: 215.59018399273302
# Run 017 | Seed: 1751428241 | Criterion value: 215.590184
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1166359865
# Crit value: 215.4700884096859
# Run 018 | Seed: 1166359865 | Criterion value: 215.470088
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1839876817
# Crit value: 214.1363483007399
# Run 019 | Seed: 1839876817 | Criterion value: 214.136348
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2010929987
# Crit value: 209.976763930694
# Run 020 | Seed: 2010929987 | Criterion value: 209.976764
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1585777864
# Crit value: 212.13796816510575
# Run 021 | Seed: 1585777864 | Criterion value: 212.137968
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1302590836
# Crit value: 205.2594288768268
# Run 022 | Seed: 1302590836 | Criterion value: 205.259429
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 917866618
# Crit value: 217.83624236248806
# Run 023 | Seed: 917866618 | Criterion value: 217.836242
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2135434929
# Crit value: 203.10679182995963
# Run 024 | Seed: 2135434929 | Criterion value: 203.106792
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 386071855
# Crit value: 211.2707063897022
# Run 025 | Seed: 386071855 | Criterion value: 211.270706
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1003566528
# Crit value: 213.2003157520246
# Run 026 | Seed: 1003566528 | Criterion value: 213.200316
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1380081934
# Crit value: 211.49020606543516
# Run 027 | Seed: 1380081934 | Criterion value: 211.490206
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1806510742
# Crit value: 219.95626518436265
# Run 028 | Seed: 1806510742 | Criterion value: 219.956265
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2032692179
# Crit value: 222.78266681169157
# Run 029 | Seed: 2032692179 | Criterion value: 222.782667
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 892482278
# Crit value: 213.89264880044811
# Run 030 | Seed: 892482278 | Criterion value: 213.892649
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1773697159
# Crit value: 215.78894513474046
# Run 031 | Seed: 1773697159 | Criterion value: 215.788945
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1361429855
# Crit value: 212.51403078043705
# Run 032 | Seed: 1361429855 | Criterion value: 212.514031
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 426959450
# Crit value: 204.03773181574448
# Run 033 | Seed: 426959450 | Criterion value: 204.037732
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 800553583
# Crit value: 217.19751423632255
# Run 034 | Seed: 800553583 | Criterion value: 217.197514
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1811985218
# Crit value: 219.4855984052191
# Run 035 | Seed: 1811985218 | Criterion value: 219.485598
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 668070106
# Crit value: 216.41353848083574
# Run 036 | Seed: 668070106 | Criterion value: 216.413538
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1525899093
# Crit value: 214.52163379570095
# Run 037 | Seed: 1525899093 | Criterion value: 214.521634
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 13828287
# Crit value: 227.61186381514733
# Run 038 | Seed: 13828287 | Criterion value: 227.611864
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1504924069
# Crit value: 205.91800937977706
# Run 039 | Seed: 1504924069 | Criterion value: 205.918009
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 381478893
# Crit value: 207.10504411742352
# Run 040 | Seed: 381478893 | Criterion value: 207.105044
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 572127408
# Crit value: 216.40065343149715
# Run 041 | Seed: 572127408 | Criterion value: 216.400653
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1740503945
# Crit value: 208.41690175488594
# Run 042 | Seed: 1740503945 | Criterion value: 208.416902
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 557774020
# Crit value: 225.5252230771959
# Run 043 | Seed: 557774020 | Criterion value: 225.525223
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1655945402
# Crit value: 217.92165576731236
# Run 044 | Seed: 1655945402 | Criterion value: 217.921656
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1266032449
# Crit value: 206.68368556907294
# Run 045 | Seed: 1266032449 | Criterion value: 206.683686
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1581741835
# Crit value: 218.2061467667107
# Run 046 | Seed: 1581741835 | Criterion value: 218.206147
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1890465029
# Crit value: 201.80640461721578
# Run 047 | Seed: 1890465029 | Criterion value: 201.806405
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 793672369
# Crit value: 210.97012913117115
# Run 048 | Seed: 793672369 | Criterion value: 210.970129
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 477480620
# Crit value: 211.95415614845797
# Run 049 | Seed: 477480620 | Criterion value: 211.954156
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1557893796
# Crit value: 213.9918770606318
# Run 050 | Seed: 1557893796 | Criterion value: 213.991877
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 719206334
# Crit value: 218.45029401789517
# Run 051 | Seed: 719206334 | Criterion value: 218.450294
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1411847498
# Crit value: 213.44562371163488
# Run 052 | Seed: 1411847498 | Criterion value: 213.445624
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 261936272
# Crit value: 211.8684283119617
# Run 053 | Seed: 261936272 | Criterion value: 211.868428
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 501383845
# Crit value: 214.5580433475713
# Run 054 | Seed: 501383845 | Criterion value: 214.558043
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1743771823
# Crit value: 207.81779776208566
# Run 055 | Seed: 1743771823 | Criterion value: 207.817798
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 921977774
# Crit value: 215.81272730125957
# Run 056 | Seed: 921977774 | Criterion value: 215.812727
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1614265156
# Crit value: 220.29040001177947
# Run 057 | Seed: 1614265156 | Criterion value: 220.290400
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1367059383
# Crit value: 200.83905649511397
# Run 090 | Seed: 1367059383 | Criterion value: 200.839056
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 42244166
# Crit value: 222.34554946388164
# Run 091 | Seed: 42244166 | Criterion value: 222.345549
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 709258324
# Crit value: 213.40727189053635
# Run 092 | Seed: 709258324 | Criterion value: 213.407272
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1192966845
# Crit value: 218.33259519077637
# Run 093 | Seed: 1192966845 | Criterion value: 218.332595
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1200510153
# Crit value: 225.33699746063226
# Run 094 | Seed: 1200510153 | Criterion value: 225.336997
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1093629428
# Crit value: 215.6082086857323
# Run 095 | Seed: 1093629428 | Criterion value: 215.608209
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1371001468
# Crit value: 209.00296720512029
# Run 096 | Seed: 1371001468 | Criterion value: 209.002967
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1531133636
# Crit value: 214.40105619955366
# Run 097 | Seed: 1531133636 | Criterion value: 214.401056
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1451459998
# Crit value: 212.1478921070441
# Run 098 | Seed: 1451459998 | Criterion value: 212.147892
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1753841161
# Crit value: 211.49382132765362
# Run 099 | Seed: 1753841161 | Criterion value: 211.493821
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2009750454
# Crit value: 204.76018109243708
# Run 100 | Seed: 2009750454 | Criterion value: 204.760181

# %% [markdown]
# ## Old model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params_old = {
    "interest_rate": 0.01,
    "income_shock_mean": 0.0,
    "income_shock_std": 0.2,
    "taste_shock_scale": 2.4,
    "discount_factor": 0.9862761291459945,
    "rho": 0.4546033105783697,
    "gamma": jnp.asarray([0.6436928, 1.3013253, 1.95873805, 1.65679825]),
    "kappa1": 0.009068366633740818,
    "kappa2": 0.001434998756969184,
    "phi": 5.711828977972858,
    "b_scale": 0.5496627563003196,
    "xi": 0.008433463067153925,
    "eta_edu": 1.10158,
    "alpha1": 0.000417,
    "alpha2": 0.099277,
    "beta0": -7.7211014099165185,
    "beta1": 0.07418311839644762,
    "beta2": -0.0005894472446704196
}

# %%
def flow_util(consumption, choice, params, period, model_specs, lagged_choice):
    # Utility parameter
    rho = params["rho"]

    # Disutility parameters
    age = (model_specs["start_age"] + period).astype(float)
    gamma = params["gamma"][choice - 1]  # remove the first element

    ##############################################
    ########## Disutility of working #############
    ##############################################
    working = choice > 0  # 1 if choice is working, 0 if not
    # -------  Zero disutility from working if unemployed

    # Age component of disutility
    age_linear = jnp.where(age >= 55, params["kappa1"] * (age - 55), 0.0)
    age_quadratic = jnp.where(age >= 55, params["kappa2"] * (age - 55) ** 2, 0.0)   
    # + age_linear

    # estimate total disutility
    disutil_0 = working * (1.0 + age_linear + age_quadratic) * gamma

    # No disutility from working, if you dont work.
    disutil = jnp.where(working, disutil_0, 0.0)  # if working == 0, disutility = 0

    ##############################################
    ############# Transaction costs  #############
    ##############################################

    # transition cost when going from working to unemployed, and vice versa
    trans_cost = jnp.where(
        choice != lagged_choice, params["phi"], 0.0
    )

    # Utility for agents that are alive.
    u = (
        ((consumption ** (1 - rho)) - 1) / (1 - rho) - disutil - trans_cost
    ) 

    return u


def marginal_utility(consumption, params):
    rho = params["rho"]
    u_prime = consumption ** (-rho)
    return u_prime


def inverse_marginal_utility(marginal_utility, params):
    rho = params["rho"]
    return marginal_utility ** (-1 / rho)


utility_functions = {
    "utility": flow_util,
    "inverse_marginal_utility": inverse_marginal_utility,
    "marginal_utility": marginal_utility,
}

# %%
old_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
old_model_solved = old_model.solve(params_old)
old_model.validate_exogenous(params_old)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for Larsen model

# %%
old_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(old_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    old_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })

old_model_crit_table = pd.DataFrame(old_model_results)

old_model_crit_table

old_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "old_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1866151575
# Crit value: 294.74273649530835
# Run 001 | Seed: 1866151575 | Criterion value: 294.742736
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 25058401
# Crit value: 295.16052181201115
# Run 002 | Seed: 25058401 | Criterion value: 295.160522
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1525452678
# Crit value: 307.9787184182999
# Run 003 | Seed: 1525452678 | Criterion value: 307.978718
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2138161417
# Crit value: 287.9424924937481
# Run 004 | Seed: 2138161417 | Criterion value: 287.942492
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1825392380
# Crit value: 315.52383219198146
# Run 005 | Seed: 1825392380 | Criterion value: 315.523832
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 211583374
# Crit value: 300.57235820429713
# Run 006 | Seed: 211583374 | Criterion value: 300.572358
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 277448489
# Crit value: 297.3237193749195
# Run 007 | Seed: 277448489 | Criterion value: 297.323719
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1038822436
# Crit value: 287.7157021399766
# Run 008 | Seed: 1038822436 | Criterion value: 287.715702
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1481216582
# Crit value: 311.05801436525667
# Run 009 | Seed: 1481216582 | Criterion value: 311.058014
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 120676320
# Crit value: 290.82302458302104
# Run 010 | Seed: 120676320 | Criterion value: 290.823025
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 76294494
# Crit value: 300.22429095055924
# Run 011 | Seed: 76294494 | Criterion value: 300.224291
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1706683972
# Crit value: 306.51916165121327
# Run 012 | Seed: 1706683972 | Criterion value: 306.519162
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 162532072
# Crit value: 288.28061161908454
# Run 013 | Seed: 162532072 | Criterion value: 288.280612
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1986979013
# Crit value: 307.55001903413773
# Run 014 | Seed: 1986979013 | Criterion value: 307.550019
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1558547857
# Crit value: 290.0116925610894
# Run 015 | Seed: 1558547857 | Criterion value: 290.011693
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1604861881
# Crit value: 304.8404804689068
# Run 016 | Seed: 1604861881 | Criterion value: 304.840480
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1643890567
# Crit value: 288.9745022745662
# Run 017 | Seed: 1643890567 | Criterion value: 288.974502
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1123458147
# Crit value: 295.9049745790005
# Run 018 | Seed: 1123458147 | Criterion value: 295.904975
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 945082934
# Crit value: 282.723927424884
# Run 019 | Seed: 945082934 | Criterion value: 282.723927
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 26996296
# Crit value: 287.545292375251
# Run 020 | Seed: 26996296 | Criterion value: 287.545292
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1083642451
# Crit value: 297.9540988499595
# Run 021 | Seed: 1083642451 | Criterion value: 297.954099
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 919541591
# Crit value: 289.6535981586433
# Run 022 | Seed: 919541591 | Criterion value: 289.653598
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1581045556
# Crit value: 297.32720154847425
# Run 023 | Seed: 1581045556 | Criterion value: 297.327202
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1041134172
# Crit value: 302.99613256400386
# Run 024 | Seed: 1041134172 | Criterion value: 302.996133
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1150790973
# Crit value: 321.9628169893227
# Run 025 | Seed: 1150790973 | Criterion value: 321.962817
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 103981954
# Crit value: 290.5443022066689
# Run 026 | Seed: 103981954 | Criterion value: 290.544302
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 881913067
# Crit value: 304.28003645368136
# Run 027 | Seed: 881913067 | Criterion value: 304.280036
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 639471867
# Crit value: 296.33509246743057
# Run 028 | Seed: 639471867 | Criterion value: 296.335092
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1574565801
# Crit value: 298.88090861777124
# Run 029 | Seed: 1574565801 | Criterion value: 298.880909
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1869283332
# Crit value: 300.2401603939048
# Run 030 | Seed: 1869283332 | Criterion value: 300.240160
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 69529038
# Crit value: 300.37229811470837
# Run 031 | Seed: 69529038 | Criterion value: 300.372298
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1899872711
# Crit value: 302.1107430033394
# Run 032 | Seed: 1899872711 | Criterion value: 302.110743
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 825965298
# Crit value: 290.20645450692086
# Run 033 | Seed: 825965298 | Criterion value: 290.206455
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1255732254
# Crit value: 298.835146589693
# Run 034 | Seed: 1255732254 | Criterion value: 298.835147
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 125021787
# Crit value: 301.3417989270113
# Run 035 | Seed: 125021787 | Criterion value: 301.341799
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 428694098
# Crit value: 304.8895068672488
# Run 036 | Seed: 428694098 | Criterion value: 304.889507
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1225402126
# Crit value: 290.89544799455837
# Run 037 | Seed: 1225402126 | Criterion value: 290.895448
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 669990744
# Crit value: 301.90861778012885
# Run 038 | Seed: 669990744 | Criterion value: 301.908618
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1932218252
# Crit value: 292.40569163173006
# Run 039 | Seed: 1932218252 | Criterion value: 292.405692
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 354357215
# Crit value: 300.38579920076165
# Run 040 | Seed: 354357215 | Criterion value: 300.385799
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1927318269
# Crit value: 294.7432041846929
# Run 041 | Seed: 1927318269 | Criterion value: 294.743204
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1045255241
# Crit value: 291.0614870280523
# Run 042 | Seed: 1045255241 | Criterion value: 291.061487
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1873473909
# Crit value: 305.0783792958401
# Run 043 | Seed: 1873473909 | Criterion value: 305.078379
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1013598768
# Crit value: 304.2507303629462
# Run 044 | Seed: 1013598768 | Criterion value: 304.250730
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 705717430
# Crit value: 298.3857210989077
# Run 045 | Seed: 705717430 | Criterion value: 298.385721
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1086502739
# Crit value: 300.9218700041499
# Run 046 | Seed: 1086502739 | Criterion value: 300.921870
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 716702762
# Crit value: 303.66602162697086
# Run 047 | Seed: 716702762 | Criterion value: 303.666022
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 65252477
# Crit value: 295.1298786618428
# Run 048 | Seed: 65252477 | Criterion value: 295.129879
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1383052489
# Crit value: 303.7940538161045
# Run 049 | Seed: 1383052489 | Criterion value: 303.794054
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 713318759
# Crit value: 290.09286921612767
# Run 050 | Seed: 713318759 | Criterion value: 290.092869
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 940413398
# Crit value: 294.5692549140794
# Run 051 | Seed: 940413398 | Criterion value: 294.569255
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1710451098
# Crit value: 304.2987600872853
# Run 052 | Seed: 1710451098 | Criterion value: 304.298760
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 5841638
# Crit value: 291.4699280104796
# Run 085 | Seed: 5841638 | Criterion value: 291.469928
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1757192358
# Crit value: 299.9976948121306
# Run 086 | Seed: 1757192358 | Criterion value: 299.997695
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 729750118
# Crit value: 294.118420284289
# Run 087 | Seed: 729750118 | Criterion value: 294.118420
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1222575742
# Crit value: 309.17541034281254
# Run 088 | Seed: 1222575742 | Criterion value: 309.175410
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1426793033
# Crit value: 304.88920699192676
# Run 089 | Seed: 1426793033 | Criterion value: 304.889207
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1685393478
# Crit value: 300.88957075832514
# Run 090 | Seed: 1685393478 | Criterion value: 300.889571
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1606324145
# Crit value: 294.227008847968
# Run 091 | Seed: 1606324145 | Criterion value: 294.227009
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 241254704
# Crit value: 301.5816185980094
# Run 092 | Seed: 241254704 | Criterion value: 301.581619
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 62004383
# Crit value: 295.10740634955334
# Run 093 | Seed: 62004383 | Criterion value: 295.107406
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1928445766
# Crit value: 295.3497948767081
# Run 094 | Seed: 1928445766 | Criterion value: 295.349795
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1035289301
# Crit value: 305.1763801636355
# Run 095 | Seed: 1035289301 | Criterion value: 305.176380
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1500494224
# Crit value: 298.7565079907624
# Run 096 | Seed: 1500494224 | Criterion value: 298.756508
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1126199002
# Crit value: 303.9560473743901
# Run 097 | Seed: 1126199002 | Criterion value: 303.956047
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1416035968
# Crit value: 302.08442140591404
# Run 098 | Seed: 1416035968 | Criterion value: 302.084421
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 753480794
# Crit value: 295.8860271057985
# Run 099 | Seed: 753480794 | Criterion value: 295.886027
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1233530201
# Crit value: 299.2429828642378
# Run 100 | Seed: 1233530201 | Criterion value: 299.242983

# %% [markdown]
# ### Plot the results from both runs

# %%
import matplotlib.pyplot as plt
import pandas as pd

old_vals = old_model_crit_table["criterion_value"]
new_vals = new_model_crit_table["criterion_value"]

summary_table = pd.DataFrame({
    "model": ["old", "new"],
    "mean": [old_vals.mean(), new_vals.mean()],
    "median": [old_vals.median(), new_vals.median()],
    "std": [old_vals.std(), new_vals.std()],
    "min": [old_vals.min(), new_vals.min()],
    "max": [old_vals.max(), new_vals.max()],
})

summary_table
# Out:
#   model        mean      median       std         min         max
# 0   old  297.864645  298.716773  7.256347  282.134994  321.962817
# 1   new  213.104907  213.296050  6.152915  199.276884  229.342008

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    old_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="Old model",
)

plt.hist(
    new_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="New model",
)

plt.axvline(old_vals.mean(), linestyle="--", label=f"Old mean: {old_vals.mean():.2f}")
plt.axvline(new_vals.mean(), linestyle="--", label=f"New mean: {new_vals.mean():.2f}")

plt.xlabel("Criterion value")
plt.ylabel("Density")
plt.title("Distribution of Criterion Values Across Seeds")
plt.legend()
plt.tight_layout()
plt.show()

# %%
crit_compare = pd.concat(
    [
        old_model_crit_table.assign(model="Old model"),
        new_model_crit_table.assign(model="New model"),
    ],
    ignore_index=True,
)

plt.figure(figsize=(7, 5))

crit_compare.boxplot(
    column="criterion_value",
    by="model",
    grid=False,
)

plt.title("Criterion Value by Model")
plt.suptitle("")
plt.xlabel("")
plt.ylabel("Criterion value")
plt.tight_layout()
plt.show()
