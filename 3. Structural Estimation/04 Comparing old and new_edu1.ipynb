# %% [markdown]
# # Structural Estimation using DC-EGM for Education Level 1

# %% [markdown]
# ## Dependencies, Packages & Roots

# %% [markdown]
# ### Magics

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Project Paths

# %%
from pathlib import Path
import sys
import importlib

# Change this depending on notebook location:
# 0 = notebook is 1 folder inside project root, e.g. dp_termpaper/edu1
# 1 = notebook is 2 folders inside project root, e.g. dp_termpaper/data/moments
# 2 = notebook is 3 folders inside project root
amount_of_levels = 0

DIR = Path.cwd().resolve().parents[amount_of_levels]

if str(DIR) not in sys.path:
    sys.path.insert(0, str(DIR))

import project_paths as pp
from project_imports import *

importlib.reload(pp)
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Load Data

# %%
###############################################################
#### Define which education level you want to estimate for ####
###############################################################

education_level_file = pp.MOMENTS_DIR / "moments_udd1.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd2.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd3.txt"

version = "phi_udd1" # for saving results, change this when you change the specification

MORTALITY = pp.DATA_DIR / "mortality.xlsx"

beta0, beta1, beta2 = np.loadtxt(pp.FIRST_STAGE_RESULTS_DIR / "wage_params_udd1_ols.txt")

# %%
# Read CSV
df_edu = pd.read_csv(education_level_file)
# read mortality and discard seoncd and third column
df_mort = pd.read_excel(MORTALITY, sheet_name="DOD", usecols=[0, 3])

# 2) standardize colomn name and remove _FREQ_ column
# Iterate over DataFrames (if there are multiple DataFrames to process)
for data_frame in [df_edu]:
    # Rename ALDER → age
    if "ALDER" in data_frame.columns:
        data_frame.rename(columns={"ALDER": "age"}, inplace=True)
    # Remove _FREQ_-column if it exists
    # if "_FREQ_" in data_frame.columns:
    #     data_frame.drop(columns=["_FREQ_"], inplace=True)
# drop var_wage, skew_wage and pens
df_edu.drop(columns=["var_wage", "skew_wage", "pens"], inplace=True)
# df_edu

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
labour_choices = np.arange(5) # 5 choices
alpha1, alpha2 = np.loadtxt(pp.STRUCTURAL_RESULTS_DIR/ "mortality_params.txt")

model_config = {
    "n_periods": n_periods,
    "choices": labour_choices, # 5 choices
    "n_quad_points": 5,
    "continuous_states": {
        "assets_end_of_period": np.linspace(0, 50, 20),
        "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
    "stochastic_states": {
        "survival": [0, 1],
    }
    }

model_specs = {
    "choices": labour_choices, # 5 choices
    "n_periods": n_periods,
    "labour_choices": labour_choices, # 5 choices
    "hours": jnp.array([0,250,750,1300,1900]), #list 
    "max_hours": 1900,
    "start_age": 30,
    "tax_threshold1": 0.480,
    "tax_threshold2": 5.698,
    "tax_base_rate": 0.38,
    "tax_top_rate": 0.5,
    "retirement_age": 67,
    "oap_base_amount": 0.80328,
    "oap_max_supplement": 0.92940,
    "supp_threshold": 0.79300,
    "oap_threshold": 3.3592,
    "supp_reduction_rate": 0.309,
    "oap_reduction_rate": 0.3,
    "alpha1": alpha1, # independently estimated parameter for survival probability
    "alpha2": alpha2,  # independently estimated parameter for survival probability
    "max_init_experience": 5,
    "max_ret_period": 45, # Age 75
    "min_ret_period": 30, # Age 60
}
stochastic_states_transitions = {
    "survival": prob_survival
}

# %% [markdown]
# ### Initial values for simulating.

# %%
# Select number of individuals for simulation
#Debug level
n_individuals = 10000

# Optimal level
# n_individuals = 250000

seed = 132
key = jax.random.PRNGKey(0)
n = n_individuals       

# hours mapping for simulation
hours_map = {0: 0, 1: 250, 2: 750, 3: 1300, 4: 1900}

#age for simulation
start_age = model_specs["start_age"] 

# distribution of initial choices
labels = jnp.array([0, 1, 2, 3, 4], dtype=jnp.int32)
probs  = jnp.array([0.259155, 0.118310, 0.108099, 0.108451, 0.405986])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)

# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals, dtype=jnp.int32),      # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 1).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals, dtype=jnp.int32), # Every individual starts with 1 (alive)
    "assets_begin_of_period": jnp.full(n_individuals, 0.505047) # Every individual starts with 59k wealth - to be adjusted based on the actual moments
}

# %% [markdown]
# ### Define Criterion function for simulating across seeds

# %%
def criterion(model_solved, seed=seed):
    
    keep_cols = ["hours_0", "hours_1","hours_2","hours_3","hours_4", "work_work", "nowork_nowork"]

    # Simulate model
    sim = model_solved.simulate(
        states_initial=states_initial,
        seed=seed,
    )

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(sim, start_age, hours_map)
    empirical_moms = df_edu.copy()  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]

    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    print("Simulated moments shape:", sim_vals.shape)
    print("Empirical moments shape:", emp_vals.shape)

    # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-10

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Seed:", seed)
    print("Crit value:", crit_val)
    return float(crit_val)

# %% [markdown]
# ## New model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params = load_params_txt(pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_phi_udd1.txt")
# If you want to see Frederiks original parameters, load optimized_params_udd1.txt instead
params["gamma"] = jnp.asarray(params["gamma"])

# %%
new_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
new_model_solved = new_model.solve(params)
new_model.validate_exogenous(params)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for my model

# %%
new_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(new_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    new_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })


new_model_crit_table = pd.DataFrame(new_model_results)

new_model_crit_table

new_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "new_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1742835283
# Crit value: 237.8926043209851
# Run 001 | Seed: 1742835283 | Criterion value: 237.892604
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1722050959
# Crit value: 233.97962538977683
# Run 002 | Seed: 1722050959 | Criterion value: 233.979625
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 766906125
# Crit value: 234.4735429533115
# Run 003 | Seed: 766906125 | Criterion value: 234.473543
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 155252609
# Crit value: 232.81482017757415
# Run 004 | Seed: 155252609 | Criterion value: 232.814820
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2067552999
# Crit value: 225.1063657885547
# Run 005 | Seed: 2067552999 | Criterion value: 225.106366
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 366791196
# Crit value: 226.20852259065313
# Run 006 | Seed: 366791196 | Criterion value: 226.208523
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 308691257
# Crit value: 227.05276300259712
# Run 007 | Seed: 308691257 | Criterion value: 227.052763
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1801392399
# Crit value: 234.38370185315657
# Run 008 | Seed: 1801392399 | Criterion value: 234.383702
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 161993747
# Crit value: 237.11764609462728
# Run 009 | Seed: 161993747 | Criterion value: 237.117646
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 150141604
# Crit value: 234.68847112694007
# Run 010 | Seed: 150141604 | Criterion value: 234.688471
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 130279264
# Crit value: 224.26869458315232
# Run 011 | Seed: 130279264 | Criterion value: 224.268695
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 654651901
# Crit value: 237.81591571403146
# Run 012 | Seed: 654651901 | Criterion value: 237.815916
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1989379951
# Crit value: 234.33051122221227
# Run 013 | Seed: 1989379951 | Criterion value: 234.330511
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1103494343
# Crit value: 236.06292706796128
# Run 014 | Seed: 1103494343 | Criterion value: 236.062927
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1072898482
# Crit value: 225.47784778155648
# Run 015 | Seed: 1072898482 | Criterion value: 225.477848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 788217053
# Crit value: 229.71985188761914
# Run 016 | Seed: 788217053 | Criterion value: 229.719852
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 165068249
# Crit value: 247.1504950853074
# Run 017 | Seed: 165068249 | Criterion value: 247.150495
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 539224319
# Crit value: 227.55502299420533
# Run 018 | Seed: 539224319 | Criterion value: 227.555023
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 274479054
# Crit value: 223.0347372544886
# Run 019 | Seed: 274479054 | Criterion value: 223.034737
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1285648111
# Crit value: 236.16815615661397
# Run 083 | Seed: 1285648111 | Criterion value: 236.168156
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 296793467
# Crit value: 230.87567840424572
# Run 084 | Seed: 296793467 | Criterion value: 230.875678
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 918557953
# Crit value: 221.8604874865881
# Run 085 | Seed: 918557953 | Criterion value: 221.860487
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1676512048
# Crit value: 239.31173400957633
# Run 086 | Seed: 1676512048 | Criterion value: 239.311734
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1961518705
# Crit value: 238.65797588961135
# Run 087 | Seed: 1961518705 | Criterion value: 238.657976
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1632704672
# Crit value: 236.3352389738243
# Run 088 | Seed: 1632704672 | Criterion value: 236.335239
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1025918693
# Crit value: 230.1733421084084
# Run 089 | Seed: 1025918693 | Criterion value: 230.173342
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1990555706
# Crit value: 225.1997292136207
# Run 090 | Seed: 1990555706 | Criterion value: 225.199729
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 412069284
# Crit value: 228.94376644110238
# Run 091 | Seed: 412069284 | Criterion value: 228.943766
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 802641453
# Crit value: 223.384419878672
# Run 092 | Seed: 802641453 | Criterion value: 223.384420
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 487322890
# Crit value: 230.54861125828606
# Run 093 | Seed: 487322890 | Criterion value: 230.548611
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 769638517
# Crit value: 233.80775198577405
# Run 094 | Seed: 769638517 | Criterion value: 233.807752
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 745752663
# Crit value: 227.03274996319962
# Run 095 | Seed: 745752663 | Criterion value: 227.032750
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1514579707
# Crit value: 235.28501041587595
# Run 096 | Seed: 1514579707 | Criterion value: 235.285010
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 979428027
# Crit value: 233.091571140259
# Run 097 | Seed: 979428027 | Criterion value: 233.091571
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2073628696
# Crit value: 238.59768297541646
# Run 098 | Seed: 2073628696 | Criterion value: 238.597683
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1016674714
# Crit value: 235.11422820605515
# Run 099 | Seed: 1016674714 | Criterion value: 235.114228
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1243954964
# Crit value: 223.64905555653894
# Run 100 | Seed: 1243954964 | Criterion value: 223.649056

# %% [markdown]
# ## Old model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params_old = {
    "interest_rate": 0.01,
    "income_shock_mean": 0.0,
    "income_shock_std": 0.14742102900070453,
    "taste_shock_scale": 1.001115695446512,
    "discount_factor": 0.964563568359607,
    "rho": 0.4454231184249471,
    "gamma": jnp.asarray([0.81221354, 1.49218307, 1.80979585, 1.40354442]),
    "beta0": -6.896104044649039,
    "beta1": 0.027168298835917603,
    "beta2": -0.0001768093349215613,
    "kappa1": 0.013789015903515455,
    "kappa2": 0.0018048522486597738,
    "phi": 1.0775170623683508,
    "alpha1": 0.000417,
    "alpha2": 0.099277,
    "b_scale": 1.1673377830168972,
    "xi": 0.39448163025955474,
    "eta_edu": 0.43848,
}

# %%
def flow_util(consumption, choice, params, period, model_specs, lagged_choice):
    # Utility parameter
    rho = params["rho"]

    # Disutility parameters
    age = (model_specs["start_age"] + period).astype(float)
    gamma = params["gamma"][choice - 1]  # remove the first element

    ##############################################
    ########## Disutility of working #############
    ##############################################
    working = choice > 0  # 1 if choice is working, 0 if not
    # -------  Zero disutility from working if unemployed

    # Age component of disutility
    age_linear = jnp.where(age >= 55, params["kappa1"] * (age - 55), 0.0)
    age_quadratic = jnp.where(age >= 55, params["kappa2"] * (age - 55) ** 2, 0.0)   
    # + age_linear

    # estimate total disutility
    disutil_0 = working * (1.0 + age_linear + age_quadratic) * gamma

    # No disutility from working, if you dont work.
    disutil = jnp.where(working, disutil_0, 0.0)  # if working == 0, disutility = 0

    ##############################################
    ############# Transaction costs  #############
    ##############################################

    # transition cost when going from working to unemployed, and vice versa
    trans_cost = jnp.where(
        choice != lagged_choice, params["phi"], 0.0
    )

    # Utility for agents that are alive.
    u = (
        ((consumption ** (1 - rho)) - 1) / (1 - rho) - disutil - trans_cost
    ) 

    return u


def marginal_utility(consumption, params):
    rho = params["rho"]
    u_prime = consumption ** (-rho)
    return u_prime


def inverse_marginal_utility(marginal_utility, params):
    rho = params["rho"]
    return marginal_utility ** (-1 / rho)


utility_functions = {
    "utility": flow_util,
    "inverse_marginal_utility": inverse_marginal_utility,
    "marginal_utility": marginal_utility,
}

# %%
old_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
old_model_solved = old_model.solve(params_old)
old_model.validate_exogenous(params_old)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for Larsen model

# %%
old_model_results = []
rng = np.random.default_rng()

for i in range(100):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(old_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    old_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })

old_model_crit_table = pd.DataFrame(old_model_results)

old_model_crit_table

old_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "old_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 252624922
# Crit value: 346.5846600250779
# Run 001 | Seed: 252624922 | Criterion value: 346.584660
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1281086751
# Crit value: 335.690211232989
# Run 002 | Seed: 1281086751 | Criterion value: 335.690211
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1103050397
# Crit value: 343.59238966974425
# Run 003 | Seed: 1103050397 | Criterion value: 343.592390
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2020337400
# Crit value: 327.1693625668922
# Run 004 | Seed: 2020337400 | Criterion value: 327.169363
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 806823727
# Crit value: 333.93775271592625
# Run 005 | Seed: 806823727 | Criterion value: 333.937753
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1186305531
# Crit value: 329.25678182015105
# Run 006 | Seed: 1186305531 | Criterion value: 329.256782
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 397228962
# Crit value: 330.00936154684655
# Run 007 | Seed: 397228962 | Criterion value: 330.009362
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1565101133
# Crit value: 339.4851191011207
# Run 008 | Seed: 1565101133 | Criterion value: 339.485119
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1011800401
# Crit value: 326.9540885468707
# Run 009 | Seed: 1011800401 | Criterion value: 326.954089
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1706098061
# Crit value: 349.2104957194348
# Run 010 | Seed: 1706098061 | Criterion value: 349.210496
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1955408499
# Crit value: 329.28536496384686
# Run 011 | Seed: 1955408499 | Criterion value: 329.285365
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 83878767
# Crit value: 330.5492715290764
# Run 012 | Seed: 83878767 | Criterion value: 330.549272
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1037835138
# Crit value: 346.68590644662675
# Run 013 | Seed: 1037835138 | Criterion value: 346.685906
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1341501196
# Crit value: 343.828023817758
# Run 014 | Seed: 1341501196 | Criterion value: 343.828024
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 811977330
# Crit value: 338.1908015947161
# Run 015 | Seed: 811977330 | Criterion value: 338.190802
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 667265309
# Crit value: 326.2954431689771
# Run 016 | Seed: 667265309 | Criterion value: 326.295443
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2035174039
# Crit value: 347.8163299253871
# Run 017 | Seed: 2035174039 | Criterion value: 347.816330
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 471062273
# Crit value: 338.798264846707
# Run 018 | Seed: 471062273 | Criterion value: 338.798265
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1263130017
# Crit value: 335.42796916623325
# Run 019 | Seed: 1263130017 | Criterion value: 335.427969
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1913908575
# Crit value: 340.011311776097
# Run 020 | Seed: 1913908575 | Criterion value: 340.011312
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1424321651
# Crit value: 336.82319589210675
# Run 084 | Seed: 1424321651 | Criterion value: 336.823196
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 665969183
# Crit value: 340.11197618576807
# Run 085 | Seed: 665969183 | Criterion value: 340.111976
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 99265010
# Crit value: 315.89657806073404
# Run 086 | Seed: 99265010 | Criterion value: 315.896578
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1600365364
# Crit value: 331.82307245617795
# Run 087 | Seed: 1600365364 | Criterion value: 331.823072
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 835399873
# Crit value: 330.00721656129986
# Run 088 | Seed: 835399873 | Criterion value: 330.007217
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1388185056
# Crit value: 346.1818225615706
# Run 089 | Seed: 1388185056 | Criterion value: 346.181823
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1650370854
# Crit value: 333.8082853197133
# Run 090 | Seed: 1650370854 | Criterion value: 333.808285
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2014109065
# Crit value: 334.3146494854965
# Run 091 | Seed: 2014109065 | Criterion value: 334.314649
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 433574328
# Crit value: 319.59989240500266
# Run 092 | Seed: 433574328 | Criterion value: 319.599892
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1672918318
# Crit value: 335.03404841949595
# Run 093 | Seed: 1672918318 | Criterion value: 335.034048
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 882317198
# Crit value: 337.84878228092805
# Run 094 | Seed: 882317198 | Criterion value: 337.848782
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1953768696
# Crit value: 328.76884053171057
# Run 095 | Seed: 1953768696 | Criterion value: 328.768841
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 961599085
# Crit value: 329.7111753518666
# Run 096 | Seed: 961599085 | Criterion value: 329.711175
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 225975244
# Crit value: 337.1033893538856
# Run 097 | Seed: 225975244 | Criterion value: 337.103389
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1989712413
# Crit value: 347.6672418805543
# Run 098 | Seed: 1989712413 | Criterion value: 347.667242
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 580718036
# Crit value: 327.074867314924
# Run 099 | Seed: 580718036 | Criterion value: 327.074867
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1627851860
# Crit value: 337.7216427541344
# Run 100 | Seed: 1627851860 | Criterion value: 337.721643

# %% [markdown]
# ### Plot the results from both runs

# %%
import matplotlib.pyplot as plt
import pandas as pd

old_vals = old_model_crit_table["criterion_value"]
new_vals = new_model_crit_table["criterion_value"]

summary_table = pd.DataFrame({
    "model": ["old", "new"],
    "mean": [old_vals.mean(), new_vals.mean()],
    "median": [old_vals.median(), new_vals.median()],
    "std": [old_vals.std(), new_vals.std()],
    "min": [old_vals.min(), new_vals.min()],
    "max": [old_vals.max(), new_vals.max()],
})

summary_table
# Out:
#   model        mean      median       std         min         max
# 0   old  335.978967  335.631814  7.191559  315.896578  349.210496
# 1   new  232.168775  232.075975  5.437754  220.581931  247.150495

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    old_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="Old model",
)

plt.hist(
    new_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="New model",
)

plt.axvline(old_vals.mean(), linestyle="--", label=f"Old mean: {old_vals.mean():.2f}")
plt.axvline(new_vals.mean(), linestyle="--", label=f"New mean: {new_vals.mean():.2f}")

plt.xlabel("Criterion value")
plt.ylabel("Density")
plt.title("Distribution of Criterion Values Across Seeds")
plt.legend()
plt.tight_layout()
plt.show()

# %%
crit_compare = pd.concat(
    [
        old_model_crit_table.assign(model="Old model"),
        new_model_crit_table.assign(model="New model"),
    ],
    ignore_index=True,
)

plt.figure(figsize=(7, 5))

crit_compare.boxplot(
    column="criterion_value",
    by="model",
    grid=False,
)

plt.title("Criterion Value by Model")
plt.suptitle("")
plt.xlabel("")
plt.ylabel("Criterion value")
plt.tight_layout()
plt.show()
