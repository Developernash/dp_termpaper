# %% [markdown]
# # Structural Estimation using DC-EGM for Education Level 1

# %% [markdown]
# ## Dependencies, Packages & Roots

# %% [markdown]
# ### Magics

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Project Paths

# %%
from pathlib import Path
import sys
import importlib

# Change this depending on notebook location:
# 0 = notebook is 1 folder inside project root, e.g. dp_termpaper/edu1
# 1 = notebook is 2 folders inside project root, e.g. dp_termpaper/data/moments
# 2 = notebook is 3 folders inside project root
amount_of_levels = 0

DIR = Path.cwd().resolve().parents[amount_of_levels]

if str(DIR) not in sys.path:
    sys.path.insert(0, str(DIR))

import project_paths as pp
from project_imports import *

importlib.reload(pp)
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Load Data

# %%
###############################################################
#### Define which education level you want to estimate for ####
###############################################################

# education_level_file = pp.MOMENTS_DIR / "moments_udd1.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd2.txt"
education_level_file = pp.MOMENTS_DIR / "moments_udd3.txt"

version = "phi_udd3" # for saving results, change this when you change the specification

MORTALITY = pp.DATA_DIR / "mortality.xlsx"

beta0, beta1, beta2 = np.loadtxt(pp.FIRST_STAGE_RESULTS_DIR / "wage_params_udd3_ols.txt")

# %%
# Read CSV
df_edu = pd.read_csv(education_level_file)
# read mortality and discard seoncd and third column
df_mort = pd.read_excel(MORTALITY, sheet_name="DOD", usecols=[0, 3])

# 2) standardize colomn name and remove _FREQ_ column
# Iterate over DataFrames (if there are multiple DataFrames to process)
for data_frame in [df_edu]:
    # Rename ALDER → age
    if "ALDER" in data_frame.columns:
        data_frame.rename(columns={"ALDER": "age"}, inplace=True)
    # Remove _FREQ_-column if it exists
    # if "_FREQ_" in data_frame.columns:
    #     data_frame.drop(columns=["_FREQ_"], inplace=True)
# drop var_wage, skew_wage and pens
df_edu.drop(columns=["var_wage", "skew_wage", "pens"], inplace=True)
# df_edu

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# # Structural Estimation

# %% [markdown]
# ## Initiatal parameters

# %%
params_initial = {}
params_initial["interest_rate"] = 0.01
params_initial["income_shock_mean"] = 0.0005219532553517839 # income shock mean
params_initial["income_shock_std"] = 0.14774217073051604 # income shock scale
params_initial["taste_shock_scale"] = 0.8993760888436477 # taste shock scale

# discount factor
params_initial["discount_factor"] = 0.8670317363226403

# parameters for the utility function
params_initial["rho"] = 0.33525540153678024

# disutility of each hours choice
params_initial["gamma"]=jnp.array([0.73525231, 1.41305136, 1.76688948, 1.41499131]) 

# wage parameters
params_initial["beta0"]=beta0
params_initial["beta1"]=beta1
params_initial["beta2"]=beta2

# Age component disutility
params_initial["kappa1"] = 0.015973282293250853
params_initial["kappa2"] = 0.0017770886345081366

# transsition cost
params_initial["phi_entry"] = 0.9897438955371012
params_initial["phi_exit"] = 0.9563144631654481
params_initial["phi_switch"] = 1.0237391344939937

# mortality parameters
params_initial["alpha1"] = 0.000417
params_initial["alpha2"] = 0.099277

# bequest parameters
params_initial["b_scale"] = 1.4414212010430716
params_initial["xi"] = 0.3460857749989469

# labor market parameters
params_initial["eta_edu"]=0.43848

params=params_initial.copy()

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
labour_choices = np.arange(5) # 5 choices
alpha1, alpha2 = np.loadtxt(pp.STRUCTURAL_RESULTS_DIR/ "mortality_params.txt")

model_config = {
    "n_periods": n_periods,
    "choices": labour_choices, # 5 choices
    "n_quad_points": 5,
    "continuous_states": {
        "assets_end_of_period": np.linspace(0, 50, 20),
        "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
    "stochastic_states": {
        "survival": [0, 1],
    }
    }

model_specs = {
    "choices": labour_choices, # 5 choices
    "n_periods": n_periods,
    "labour_choices": labour_choices, # 5 choices
    "hours": jnp.array([0,250,750,1300,1900]), #list 
    "max_hours": 1900,
    "start_age": 30,
    "tax_threshold1": 0.480,
    "tax_threshold2": 5.698,
    "tax_base_rate": 0.38,
    "tax_top_rate": 0.5,
    "retirement_age": 67,
    "oap_base_amount": 0.80328,
    "oap_max_supplement": 0.92940,
    "supp_threshold": 0.79300,
    "oap_threshold": 3.3592,
    "supp_reduction_rate": 0.309,
    "oap_reduction_rate": 0.3,
    "alpha1": alpha1, # independently estimated parameter for survival probability
    "alpha2": alpha2,  # independently estimated parameter for survival probability
    "max_init_experience": 5,
    "max_ret_period": 45, # Age 75
    "min_ret_period": 30, # Age 60
}
stochastic_states_transitions = {
    "survival": prob_survival
}

# %% [markdown]
# ### Setup the model

# %%
model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %% [markdown]
# ### Initial values for simulating.

# %%
# Select number of individuals for simulation
# Optimal level
n_individuals = 100000

seed = 132
key = jax.random.PRNGKey(0)
n = n_individuals       

# hours mapping for simulation
hours_map = {0: 0, 1: 250, 2: 750, 3: 1300, 4: 1900}

#age for simulation
start_age = model_specs["start_age"] 

# distribution of initial choices
labels = jnp.array([0, 1, 2, 3, 4], dtype=jnp.int32)
probs  = jnp.array([0.259155, 0.118310, 0.108099, 0.108451, 0.405986])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)

# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals, dtype=jnp.int32),      # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 1).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals, dtype=jnp.int32), # Every individual starts with 1 (alive)
    "assets_begin_of_period": jnp.full(n_individuals, 0.505047) # Every individual starts with 59k wealth - to be adjusted based on the actual moments
}

# %% [markdown]
# # Estimation

# %%
keep_cols = ["hours_0", "hours_1","hours_2","hours_3","hours_4", "work_work", "nowork_nowork"]
share_cols = keep_cols

# Helper function for params into critical function
def theta_to_params(theta_array, base_params):
    p = base_params.copy()

    p["interest_rate"] = 0.01
    p["beta0"] = beta0
    p["beta1"] = beta1
    p["beta2"] = beta2

    p["income_shock_mean"] = theta_array[0]
    p["income_shock_std"] = theta_array[1]
    p["taste_shock_scale"] = theta_array[2]
    p["discount_factor"] = theta_array[3]
    p["rho"] = theta_array[4]
    p["gamma"] = jnp.array([
        theta_array[5],
        theta_array[6],
        theta_array[7],
        theta_array[8],
    ])
    p["kappa1"] = theta_array[9]
    p["kappa2"] = theta_array[10]

    p["phi_entry"] = theta_array[11]
    p["phi_exit"] = theta_array[12]
    p["phi_switch"] = theta_array[13]

    p["b_scale"] = theta_array[14]
    p["xi"] = theta_array[15]

    p.pop("phi", None)
    
    return p

# Helper function for determining variance in empirical moments
def compute_empirical_share_variances(df, share_cols, freq_col="_FREQ_"):
    df_var = df[["age", freq_col] + share_cols].copy()

    for col in share_cols:
        p = df_var[col]
        n = df_var[freq_col]
        df_var[col] = p * (1 - p) / n

    return df_var

base_params = params_initial.copy()
empirical_var = compute_empirical_share_variances(df_edu, share_cols)

# %%
def crit_func_scipy(theta_array):
    """
    High-level objective function for MSM that updates all parameters,
    runs the simulation, computes simulated moments and compares them
    to empirical moments. The objective is the weighted sum of squared differences,
    where the weights are given by the inverse of the variances of the empirical moments.
    
    theta_array: a numpy array with 16 elements corresponding to:
       [income_shock_mean, income_shock_std, taste_shock_scale, beta, rho, gamma1, gamma2, gamma3,
        beta0, beta1, beta2, kappa1, kappa2, phi_entry, phi_exit, phi_switch]
    """

    # Convert theta vector into clean parameter dictionary
    p = theta_to_params(theta_array, base_params=base_params)

    print("Parameter dictionary used:")
    for key, value in p.items():
        print(f"{key}: {value}")

    # Validate exogenous parameters
    model.validate_exogenous(p)

    # Solve model at current parameter vector
    model_solved = model.solve(p)

    # Simulate model
    sim = model_solved.simulate(
        states_initial=states_initial,
        seed=seed,
    )

    # df_sim = create_simulation_df(sim)

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(sim, start_age, hours_map)
    empirical_moms = df_edu  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]
    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    print("Simulated moments shape:", sim_vals.shape)
    print("Empirical moments shape:", emp_vals.shape)

        # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-6

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Crit value:", crit_val)
    print('')
    return float(crit_val)


flat_params = [
    params_initial["income_shock_mean"],
    params_initial["income_shock_std"],
    params_initial["taste_shock_scale"],
    params_initial["discount_factor"],
    params_initial["rho"],
    *params_initial["gamma"].tolist(),
    params_initial["kappa1"],
    params_initial["kappa2"],
    params_initial["phi_entry"],
    params_initial["phi_exit"],
    params_initial["phi_switch"],
    params_initial["b_scale"],
    params_initial["xi"],
]

initial_guess = np.array(flat_params, dtype=float)
result = minimize(crit_func_scipy, initial_guess, method="Nelder-Mead", options={'disp': True})
print("Optimization result:")
print(result)
# Out:
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.8857945116799
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005480509181193731
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.8878638453879
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.15512927926704184
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.78810089281865
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.9443448932858302
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 265.1776218386762
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.9103833231387723
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 289.2974152917117
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.35201817161361926
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.133098770944
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.77201493 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 283.7735365307175
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.48370393 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 287.4070454009848
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.85523395 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 274.3361939555701
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.48574088]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 274.41168793258026
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016771946407913397
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 275.81872611989024
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0018659430662335435
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 279.12426146385957
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 1.0392310903139563
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 276.34302468575305
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 1.0041301863237206
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 275.34223917289523
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0749260912186933
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 278.6369264138476
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.5134922610952253
# xi: 0.3460857749989469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.8882710030955
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005219532553517839
# income_shock_std: 0.14774217073051604
# taste_shock_scale: 0.8993760888436477
# discount_factor: 0.8670317363226403
# rho: 0.33525540153678024
# gamma: [0.73525231 1.41305136 1.76688948 1.41499131]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015973282293250853
# kappa2: 0.0017770886345081366
# phi_entry: 0.9897438955371012
# phi_exit: 0.9563144631654481
# phi_switch: 1.0237391344939937
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4414212010430716
# xi: 0.36339006374889427
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.9151824520476
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005252154631977322
# income_shock_std: 0.14866555929758168
# taste_shock_scale: 0.9049971893989199
# discount_factor: 0.8236801495065087
# rho: 0.3373507477963851
# gamma: [0.73984764 1.42188293 1.77793254 1.42383501]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016073115307583666
# kappa2: 0.0017881954384738126
# phi_entry: 0.9959297948842081
# phi_exit: 0.9622914285602322
# phi_switch: 1.030137504084581
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4504300835495902
# xi: 0.34824881109269046
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 275.5474454468537
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005256232391784759
# income_shock_std: 0.14878098286846492
# taste_shock_scale: 0.905699826968329
# discount_factor: 0.8616127879706241
# rho: 0.33761266607883567
# gamma: [0.74042205 1.34350274 1.77931292 1.42494047]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016085594434375267
# kappa2: 0.001789583788969522
# phi_entry: 0.9967030323025965
# phi_exit: 0.9630385492345801
# phi_switch: 1.0309373002834046
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.451556193862905
# xi: 0.3485191906044084
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 262.3806232371925
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005274582310918219
# income_shock_std: 0.14930038893743935
# taste_shock_scale: 0.9088616960306695
# discount_factor: 0.8589033137946163
# rho: 0.3387912983498633
# gamma: [0.74300692 1.27340214 1.78552464 1.42991505]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016141750504937477
# kappa2: 0.0017958313662002146
# phi_entry: 1.0001826006853443
# phi_exit: 0.9664005922691459
# phi_switch: 1.0345363831781098
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4566236902728216
# xi: 0.34973589840713903
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 259.2226265610972
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005263113611459805
# income_shock_std: 0.14897576014433034
# taste_shock_scale: 0.9068855278667067
# discount_factor: 0.8605967351546211
# rho: 0.338054653180471
# gamma: [0.70003344 1.39669915 1.78164232 1.42680593]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01610665296083609
# kappa2: 0.0017919266304310317
# phi_entry: 0.9980078704461268
# phi_exit: 0.9642993153725423
# phi_switch: 1.0322869563689192
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4534565050166242
# xi: 0.34897545603043234
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 259.2113578893271
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005284904140430789
# income_shock_std: 0.14959255485123746
# taste_shock_scale: 0.910640247378236
# discount_factor: 0.8573792345706113
# rho: 0.3394542790023165
# gamma: [0.66404269 1.38852305 1.78901874 1.43271325]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016173338294628706
# kappa2: 0.0017993456283924795
# phi_entry: 1.0021398579006395
# phi_exit: 0.9682917414760892
# phi_switch: 1.036560867306382
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4594741570034007
# xi: 0.3504202965461751
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 250.1089040134423
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005271285059823925
# income_shock_std: 0.14920705815942048
# taste_shock_scale: 0.9082935476835303
# discount_factor: 0.8593901724356174
# rho: 0.33857951286366306
# gamma: [0.72789485 1.39363312 1.78440847 1.42902118]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016131659961008328
# kappa2: 0.0016947475189754918
# phi_entry: 0.9995573657415693
# phi_exit: 0.9657964751613726
# phi_switch: 1.0338896729704676
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4557131245116652
# xi: 0.3495172712238359
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 259.39793728710913
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005277754123112184
# income_shock_std: 0.14939016908803354
# taste_shock_scale: 0.9094082300385156
# discount_factor: 0.8584349769497395
# rho: 0.3389950267795233
# gamma: [0.72697517 1.39120584 1.78659835 1.43077491]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01615145716947801
# kappa2: 0.001773309311259318
# phi_entry: 1.0007840495171276
# phi_exit: 0.9669817266608631
# phi_switch: 0.9775731639647398
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4574996149452395
# xi: 0.349946208251947
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 265.65692275198904
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005285031819311479
# income_shock_std: 0.14959616888272326
# taste_shock_scale: 0.9106622476878741
# discount_factor: 0.857360382028127
# rho: 0.3394624799348662
# gamma: [0.72594053 1.38847514 1.78906196 1.43274786]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016173729029006406
# kappa2: 0.0017728368958532157
# phi_entry: 0.9464909746406689
# phi_exit: 0.9683151345977898
# phi_switch: 1.0229893743732825
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4595094166830105
# xi: 0.350428762408572
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 259.8179418611865
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005293219227535683
# income_shock_std: 0.14982791865174916
# taste_shock_scale: 0.9120730175434024
# discount_factor: 0.8561514627413129
# rho: 0.339988364734627
# gamma: [0.72477655 1.38540312 1.79183352 1.43496743]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015300287741980483
# kappa2: 0.0017723054285213504
# phi_entry: 0.9905715543054701
# phi_exit: 0.9698152185268327
# phi_switch: 1.022895654358194
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4617704436380028
# xi: 0.3509716358347752
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 258.8175411177129
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005265730223520996
# income_shock_std: 0.14904982500395442
# taste_shock_scale: 0.9073363955061906
# discount_factor: 0.9035619637117953
# rho: 0.3382227205923024
# gamma: [0.71829734 1.37201157 1.78252808 1.42751529]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01590251539660982
# kappa2: 0.0017592123733116169
# phi_entry: 0.9837158748860209
# phi_exit: 0.9647787268778738
# phi_switch: 1.0155920535518081
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4541791061425355
# xi: 0.3491489528337921
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 262.76618266191156
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005304127010730872
# income_shock_std: 0.1501366703551999
# taste_shock_scale: 0.9139525343942807
# discount_factor: 0.8647766553193081
# rho: 0.34068898173384743
# gamma: [0.7207733  1.37571317 1.79552596 1.43792448]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015993502548862504
# kappa2: 0.001768084644627728
# phi_entry: 0.9891482716517428
# phi_exit: 0.9180210366836545
# phi_switch: 1.020972038024622
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4647827267864875
# xi: 0.3516948861568914
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 255.84484316521963
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005314701317882503
# income_shock_std: 0.15043598280828535
# taste_shock_scale: 0.9157745900881098
# discount_factor: 0.8644947701938916
# rho: 0.34136817925848084
# gamma: [0.71896342 1.37104589 1.79910552 1.36119786]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01599603008081396
# kappa2: 0.001766959145892677
# phi_entry: 0.9890738186660728
# phi_exit: 0.9610500815317029
# phi_switch: 1.0206261509659509
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4677029175044143
# xi: 0.3523960250516345
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 260.0292801353707
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005326597413428085
# income_shock_std: 0.15077270931800651
# taste_shock_scale: 0.9178244027436675
# discount_factor: 0.864177649427798
# rho: 0.3421322764736934
# gamma: [0.71692731 1.36579521 1.703745   1.42522325]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01599887355425935
# kappa2: 0.0017656929598157444
# phi_entry: 0.9889900590571943
# phi_exit: 0.9616420338274847
# phi_switch: 1.0202370280249458
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.470988132062082
# xi: 0.35318480630822036
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 273.3309443006104
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005339980520916868
# income_shock_std: 0.15115152664144282
# taste_shock_scale: 0.92013044198117
# discount_factor: 0.8638208885659426
# rho: 0.34299188584080753
# gamma: [0.71463668 1.35988819 1.78419641 1.42650224]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016002072461885418
# kappa2: 0.0017642685004791952
# phi_entry: 0.9888958294972059
# phi_exit: 0.9623079801602392
# phi_switch: 1.0197992647163145
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4746839984394584
# xi: 0.3346048603781888
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 254.52504079615693
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005355036516841748
# income_shock_std: 0.1515776961303087
# taste_shock_scale: 0.9227247361233604
# discount_factor: 0.8634195325963554
# rho: 0.34395894637881097
# gamma: [0.71205973 1.35324279 1.78635978 1.42794111]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016005671232964737
# kappa2: 0.0017626659837255776
# phi_entry: 0.9887898212422193
# phi_exit: 0.963057169784588
# phi_switch: 1.0193067809941043
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.3977619055553339
# xi: 0.3504740348005414
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 253.6713298120091
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005078375806121856
# income_shock_std: 0.15205713680528282
# taste_shock_scale: 0.9256433170333247
# discount_factor: 0.8629680071305696
# rho: 0.3450468894840649
# gamma: [0.70916066 1.34576672 1.78879356 1.42955983]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016009719850428976
# kappa2: 0.0017608631523777576
# phi_entry: 0.9886705619553591
# phi_exit: 0.9639000081119806
# phi_switch: 1.0187527368066185
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4643755536715202
# xi: 0.35102256727574066
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 253.28752506320345
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005321707840373251
# income_shock_std: 0.15259650756462867
# taste_shock_scale: 0.9289267205570342
# discount_factor: 0.8624600409815608
# rho: 0.34627082547747545
# gamma: [0.7058992  1.33735614 1.79153157 1.4313809 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016014274545076243
# kappa2: 0.0017588349671114603
# phi_entry: 0.9885363952576414
# phi_exit: 0.964848201230297
# phi_switch: 1.0181294370956966
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.467244847750076
# xi: 0.35163966631033994
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 253.2446662839047
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005334479751230178
# income_shock_std: 0.14489280256530118
# taste_shock_scale: 0.9326205495212079
# discount_factor: 0.8618885790639257
# rho: 0.3476477534700624
# gamma: [0.70223006 1.32789424 1.79461183 1.4334296 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016019398576554413
# kappa2: 0.0017565532586868758
# phi_entry: 0.9883854577227089
# phi_exit: 0.9659149184884033
# phi_switch: 1.0174282249209092
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4704728035884513
# xi: 0.3523339027242641
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 254.4923432866029
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005228400183545192
# income_shock_std: 0.14851438417024843
# taste_shock_scale: 0.9160217539683806
# discount_factor: 0.864456532163284
# rho: 0.3414603131576954
# gamma: [0.71871791 1.37041277 1.86911467 1.42422345]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015996372943332796
# kappa2: 0.0017668064707381595
# phi_entry: 0.9890637190358051
# phi_exit: 0.9611214584089813
# phi_switch: 1.0205792310019524
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4408414565102374
# xi: 0.34512850846699605
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 252.067826527534
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005336573497208858
# income_shock_std: 0.1516414494377054
# taste_shock_scale: 0.936550776008992
# discount_factor: 0.8612805447485221
# rho: 0.330254685710779
# gamma: [0.6983261  1.3178268  1.81874834 1.43560941]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016024850535601536
# kappa2: 0.0017541255255745201
# phi_entry: 0.9882248604932362
# phi_exit: 0.9670499034764597
# phi_switch: 1.0166821365963994
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4703359194626433
# xi: 0.35210788145977556
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 246.5629087047952
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005395093969054368
# income_shock_std: 0.15359108879130012
# taste_shock_scale: 0.955138119591664
# discount_factor: 0.8584049489614629
# rho: 0.3193729427593588
# gamma: [0.679863   1.27021452 1.84467777 1.44591845]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016050634656776877
# kappa2: 0.001742643971107712
# phi_entry: 0.9874653429713036
# phi_exit: 0.9724176236319657
# phi_switch: 1.0131536376476022
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.484793278672429
# xi: 0.35511893469018996
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 254.6370174460893
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005285704349376596
# income_shock_std: 0.15027486112389687
# taste_shock_scale: 0.9299114530604338
# discount_factor: 0.8702330000962706
# rho: 0.3421852879112819
# gamma: [0.70302211 1.33049994 1.80305822 1.42043012]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01583084983013982
# kappa2: 0.0017555068756127386
# phi_entry: 0.9756148078852234
# phi_exit: 0.9563911620829941
# phi_switch: 1.0677367287046107
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4558620436251517
# xi: 0.348517657357754
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 242.3001561249443
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005289679462508801
# income_shock_std: 0.15071720714182857
# taste_shock_scale: 0.9401630645713928
# discount_factor: 0.8761320116695361
# rho: 0.3437804184771611
# gamma: [0.69104558 1.300147   1.81128815 1.41525772]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015670546160470727
# kappa2: 0.0017466056577894488
# phi_entry: 0.963030187069271
# phi_exit: 0.9510958797940594
# phi_switch: 1.112818511074546
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4550432579651078
# xi: 0.3478033819106574
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 234.71630694374528
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005352694282594812
# income_shock_std: 0.15229473903282842
# taste_shock_scale: 0.8944520612238142
# discount_factor: 0.8627737751417315
# rho: 0.3469905402715726
# gamma: [0.68921913 1.29454137 1.82831692 1.43624702]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015971182689769457
# kappa2: 0.0017479171802740846
# phi_entry: 0.9833157483067709
# phi_exit: 0.9664061026569857
# phi_switch: 1.032705680247926
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4736432146425744
# xi: 0.3525927914747179
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 243.21368783580243
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005317367119975882
# income_shock_std: 0.1513926990129993
# taste_shock_scale: 0.929850017218157
# discount_factor: 0.8211450241813187
# rho: 0.3451191986759594
# gamma: [0.70253932 1.32589739 1.81840193 1.42481451]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01605053299805545
# kappa2: 0.0017643815423409124
# phi_entry: 0.9892937531354451
# phi_exit: 0.9581452609169492
# phi_switch: 1.0429919645271264
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4633183231056148
# xi: 0.34996009346998846
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 263.52459687553494
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005278639447634717
# income_shock_std: 0.14963554350621563
# taste_shock_scale: 0.9129648009341822
# discount_factor: 0.8829577288291761
# rho: 0.33994684011321663
# gamma: [0.71435784 1.36048302 1.79149654 1.42684009]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015939519796971228
# kappa2: 0.0017605046655689406
# phi_entry: 0.9851103444483769
# phi_exit: 0.9631203603876426
# phi_switch: 1.0224420312956377
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4564639103833055
# xi: 0.3493517379928412
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 253.7251420802593
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005263888291833403
# income_shock_std: 0.14990648629590964
# taste_shock_scale: 0.9210605989919967
# discount_factor: 0.862520087528633
# rho: 0.3417960726166229
# gamma: [0.70129755 1.32554271 1.80087336 1.49933721]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015949954528370967
# kappa2: 0.0017558279597193853
# phi_entry: 0.983440375078181
# phi_exit: 0.9621326911201125
# phi_switch: 1.038184852154194
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4483896358535975
# xi: 0.3463324853697969
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 260.6821360641858
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005301998061370228
# income_shock_std: 0.15030360868019144
# taste_shock_scale: 0.9170960923140815
# discount_factor: 0.864001099527577
# rho: 0.34147515259801636
# gamma: [0.71454695 1.3596701  1.79954748 1.3957327 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015984511192703214
# kappa2: 0.0017641763493493542
# phi_entry: 0.9876654577690999
# phi_exit: 0.9613207339288052
# phi_switch: 1.0250158262630116
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.46287459709171
# xi: 0.3508801401311751
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 252.55250015337134
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000529567857066177
# income_shock_std: 0.1508347301961553
# taste_shock_scale: 0.9269771719705084
# discount_factor: 0.870484565381829
# rho: 0.34395335602313126
# gamma: [0.69289624 1.30451283 1.81222762 1.42316032]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01574860335064062
# kappa2: 0.0017488676414458642
# phi_entry: 1.0311700294946387
# phi_exit: 0.9539933379704024
# phi_switch: 1.0360749352330787
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4570037842260888
# xi: 0.34835617022818477
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 241.7498669980454
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005312474519004057
# income_shock_std: 0.1514272999240499
# taste_shock_scale: 0.9316813250107241
# discount_factor: 0.8698415740926151
# rho: 0.34550805348926805
# gamma: [0.68656709 1.28821482 1.82035849 1.4261544 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015742790342342737
# kappa2: 0.0018337220336323845
# phi_entry: 0.9820552213628719
# phi_exit: 0.9550366052579484
# phi_switch: 1.02544779441872
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.460961408861737
# xi: 0.34912252378846453
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 244.521233302004
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005313913793920492
# income_shock_std: 0.15159983301935737
# taste_shock_scale: 0.9339656302860919
# discount_factor: 0.871695715270866
# rho: 0.3461358623954933
# gamma: [0.66440004 1.41029737 1.82359656 1.42479045]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015682829778089248
# kappa2: 0.0017373745198366831
# phi_entry: 0.979164064003788
# phi_exit: 0.9530119897737754
# phi_switch: 1.023665010616154
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4605930579241955
# xi: 0.348827224777827
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 241.98848447738015
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005297863698101126
# income_shock_std: 0.15129379260099862
# taste_shock_scale: 0.933490885366195
# discount_factor: 0.8763905978903637
# rho: 0.34570723321833785
# gamma: [0.67508335 1.30140818 1.82125806 1.41846594]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016572110295559845
# kappa2: 0.0017565340939299638
# phi_entry: 0.9873491740959521
# phi_exit: 0.9474969599219563
# phi_switch: 1.0354019089683155
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4552991313447885
# xi: 0.34732343596807247
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 237.32704131840526
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000528617300082722
# income_shock_std: 0.15112968117827275
# taste_shock_scale: 0.9340536623868059
# discount_factor: 0.8692171481337501
# rho: 0.34563389765467867
# gamma: [0.67337536 1.30181001 1.82078213 1.41307657]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015951221457014983
# kappa2: 0.0017593110589863657
# phi_entry: 0.9885475695552055
# phi_exit: 1.0029756321699221
# phi_switch: 1.0391292591698487
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4511013987660912
# xi: 0.34605375437235386
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 237.85319287828924
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005243593550630021
# income_shock_std: 0.15011209420913352
# taste_shock_scale: 0.929616157350621
# discount_factor: 0.8708474473330918
# rho: 0.3436612450244525
# gamma: [0.67435431 1.31037521 1.8366849  1.4228206 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01593629516838327
# kappa2: 0.0017625075229482944
# phi_entry: 0.9887564792169923
# phi_exit: 0.963772145194548
# phi_switch: 1.0427182817848477
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4382523021539493
# xi: 0.3645748919003271
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 236.36523462923978
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005237733545241691
# income_shock_std: 0.15702322974075417
# taste_shock_scale: 0.91675050078926
# discount_factor: 0.8738996153687544
# rho: 0.33850706383949636
# gamma: [0.68327646 1.34017928 1.8315286  1.41456712]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015908581127692882
# kappa2: 0.0017709670477732919
# phi_entry: 0.9893132286782746
# phi_exit: 0.9598973602046519
# phi_switch: 1.0482505786882457
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4384359343256437
# xi: 0.34837597320125957
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 243.5428394750921
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005288460611038022
# income_shock_std: 0.15320394957915703
# taste_shock_scale: 0.9368794618581704
# discount_factor: 0.8516982014209511
# rho: 0.34602800516212706
# gamma: [0.66726352 1.30505253 1.83964791 1.41962251]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015984592573616275
# kappa2: 0.001768323438666771
# phi_entry: 0.9931137024813439
# phi_exit: 0.9622890432825388
# phi_switch: 1.0464628407375935
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4501913305235816
# xi: 0.3512361673337348
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 240.88850712653152
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005203741553605524
# income_shock_std: 0.15146507863616998
# taste_shock_scale: 0.9288888673858438
# discount_factor: 0.8697712312568464
# rho: 0.3422745312444473
# gamma: [0.6639621  1.30626898 1.85144569 1.41748167]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015915806305204207
# kappa2: 0.0017668693023777824
# phi_entry: 0.989974710842392
# phi_exit: 0.9622562180728373
# phi_switch: 1.0529925985070632
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.515447013472584
# xi: 0.35020913709268386
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 233.85673311440837
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005128094071987412
# income_shock_std: 0.15140876988910063
# taste_shock_scale: 0.9319709330170856
# discount_factor: 0.872947080587092
# rho: 0.3414323236772654
# gamma: [0.63991328 1.28278207 1.88398864 1.41225194]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01587087384132394
# kappa2: 0.0017689709617038848
# phi_entry: 0.9905671556424784
# phi_exit: 0.961855742216962
# phi_switch: 1.0698355072635426
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.574289567431209
# xi: 0.35007668823875515
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 230.1780154255259
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005486617047558611
# income_shock_std: 0.15090459209667312
# taste_shock_scale: 0.9267612384738493
# discount_factor: 0.8714701409046974
# rho: 0.3407347674133434
# gamma: [0.65820525 1.30587197 1.86091129 1.41369946]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01589440193660184
# kappa2: 0.0017696856098913683
# phi_entry: 0.9903310443401423
# phi_exit: 0.9611578465085673
# phi_switch: 1.0599319890016643
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4625726170763595
# xi: 0.34954236973786135
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 233.6243760848497
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005263898664205385
# income_shock_std: 0.1501537319038328
# taste_shock_scale: 0.9232071496897416
# discount_factor: 0.8731043695440983
# rho: 0.33881882416191633
# gamma: [0.65550496 1.31034703 1.86684574 1.40966821]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015874863165895266
# kappa2: 0.0017730701255051547
# phi_entry: 0.9906895421731725
# phi_exit: 0.9597483590500346
# phi_switch: 1.065780607700832
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4591192941635884
# xi: 0.34866310863170236
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 235.65448825035455
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005278846018562804
# income_shock_std: 0.15242789619122527
# taste_shock_scale: 0.935801660104652
# discount_factor: 0.8727012197501473
# rho: 0.3432824559868631
# gamma: [0.63947696 1.28186769 1.86724211 1.44705834]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015890920514917306
# kappa2: 0.0017688404652867352
# phi_entry: 0.9919384902122229
# phi_exit: 0.9630792794916803
# phi_switch: 1.0639898162132448
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4630201319559397
# xi: 0.34914550587343307
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 231.05405173055658
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005358749625765042
# income_shock_std: 0.15470630970379035
# taste_shock_scale: 0.9393484867173869
# discount_factor: 0.8732763730627982
# rho: 0.3435250632808299
# gamma: [0.62540088 1.26005688 1.79744085 1.42142196]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01586587721073579
# kappa2: 0.0017664645932165017
# phi_entry: 0.99089957534257
# phi_exit: 0.9635232826468414
# phi_switch: 1.0738527346257154
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4878256069681246
# xi: 0.3553992622134168
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 230.61557582214047
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005311476354546228
# income_shock_std: 0.15426735837937045
# taste_shock_scale: 0.9483185232249254
# discount_factor: 0.8823408129669943
# rho: 0.346039945471023
# gamma: [0.67524587 1.22588833 1.87858955 1.41152075]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015650479223953268
# kappa2: 0.0017298153061651848
# phi_entry: 0.9764184011579766
# phi_exit: 0.9557569422260777
# phi_switch: 1.0625325817362024
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4727368377205519
# xi: 0.3507298448426429
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 236.35972183828116
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005256669854935331
# income_shock_std: 0.15254670241061064
# taste_shock_scale: 0.923878962996161
# discount_factor: 0.8810720363163924
# rho: 0.3572126962325909
# gamma: [0.63807743 1.28509227 1.8563401  1.40561351]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.0157521705690244
# kappa2: 0.0017719966315569774
# phi_entry: 0.9888575911484727
# phi_exit: 0.9555871600694095
# phi_switch: 1.0881426180886602
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4621751900435482
# xi: 0.3488700053519008
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 231.43185105900614
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005273793250131539
# income_shock_std: 0.15290077723508622
# taste_shock_scale: 0.9277731187426086
# discount_factor: 0.8739148147502718
# rho: 0.34342240879701724
# gamma: [0.64377524 1.31431394 1.85922765 1.41250091]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.0160354032906184
# kappa2: 0.0016846844482396872
# phi_entry: 0.9958775265020372
# phi_exit: 0.9676692776393534
# phi_switch: 1.0872138132250821
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4717014232921808
# xi: 0.3518237982186415
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 230.4311035766104
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005353041687005137
# income_shock_std: 0.14678954085517354
# taste_shock_scale: 0.9440817702082414
# discount_factor: 0.8698586733968221
# rho: 0.35103781656647903
# gamma: [0.64212821 1.2591163  1.85151992 1.4238299 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015885465275633948
# kappa2: 0.0017366541091570794
# phi_entry: 0.9894400564146046
# phi_exit: 0.9637800123719877
# phi_switch: 1.069281433272661
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4983850839490915
# xi: 0.3530013269330189
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 233.6182337788799
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005238124375203307
# income_shock_std: 0.15082988179089235
# taste_shock_scale: 0.9725839233967405
# discount_factor: 0.8818701259057311
# rho: 0.34306024967126614
# gamma: [0.63029918 1.30032608 1.85763198 1.40059787]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015812149036790436
# kappa2: 0.0017582960927666614
# phi_entry: 0.9962030752995876
# phi_exit: 0.9569430086340291
# phi_switch: 1.0893983008410721
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.466270537295475
# xi: 0.3488355755918483
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 227.97149989149108
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005180839421507555
# income_shock_std: 0.1500974531699243
# taste_shock_scale: 1.0116498544832038
# discount_factor: 0.891418301287731
# rho: 0.341095104371113
# gamma: [0.60083921 1.30321843 1.8722895  1.38277329]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.015732632210300926
# kappa2: 0.00176348554901295
# phi_entry: 1.0026467387959959
# phi_exit: 0.952211461622551
# phi_switch: 1.1177446111376454
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4625841986219248
# xi: 0.3469569676504134
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 232.21217145847163
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005267431186537978
# income_shock_std: 0.1514285439008053
# taste_shock_scale: 0.9378976409732938
# discount_factor: 0.8742199871059548
# rho: 0.34353047595681707
# gamma: [0.65085566 1.17082367 1.86660677 1.40903037]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.016116666855808294
# kappa2: 0.0017714539498203102
# phi_entry: 1.0024846360145454
# phi_exit: 0.9708284988747711
# phi_switch: 1.106655631750959
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4800303789352638
# xi: 0.35260218614049177
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 237.75805965943474
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005282135486781225
# income_shock_std: 0.15226787343708864
# taste_shock_scale: 0.9462511579142254
# discount_factor: 0.8758980647105075
# rho: 0.34566012232088994
# gamma: [0.61710439 1.25989707 1.8847731  1.40889425]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01609690122140288
# kappa2: 0.0017627841167579344
# phi_entry: 0.946892996338683
# phi_exit: 0.9719515457911903
# phi_switch: 1.1030682941987693
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.4864979769720175
# xi: 0.35360399267917253
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 226.3501553416279
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005275363944840952
# income_shock_std: 0.15298444505755532
# taste_shock_scale: 0.9558881508860839
# discount_factor: 0.8786048143748468
# rho: 0.3465135054697692
# gamma: [0.57920846 1.23758919 1.92104584 1.40176121]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01627105015678401
# kappa2: 0.001769742354413969
# phi_entry: 0.904754479760705
# phi_exit: 0.980930649701584
# phi_switch: 1.1365649736816144
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.5012450733449816
# ...
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245580870521392
# xi: 0.4150975041060798
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01242351825337
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856941790058
# income_shock_std: 0.16029471241598398
# taste_shock_scale: 0.9104607877260545
# discount_factor: 0.9128963977869591
# rho: 0.3534018760472286
# gamma: [0.56107675 1.1382997  1.68758194 1.5802097 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01289760363737477
# kappa2: 0.0017746163561680399
# phi_entry: 1.109118361602323
# phi_exit: 0.7242915321735113
# phi_switch: 1.449416183326142
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581266000987
# xi: 0.41509747901621574
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000577785676295568
# income_shock_std: 0.16029471446174148
# taste_shock_scale: 0.9104607163184216
# discount_factor: 0.9128964620721114
# rho: 0.3534020283653284
# gamma: [0.56107691 1.13829927 1.68758179 1.5802092 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897621359735356
# kappa2: 0.001774616142585624
# phi_entry: 1.1091178714015264
# phi_exit: 0.7242912564949129
# phi_switch: 1.4494159373965623
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455820328606348
# xi: 0.41509733401752946
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.0126387622752
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855744258154
# income_shock_std: 0.1602946863122926
# taste_shock_scale: 0.9104608493966071
# discount_factor: 0.9128963724792889
# rho: 0.353401765813792
# gamma: [0.56107673 1.1382997  1.68758208 1.58020979]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897595296815804
# kappa2: 0.0017746162856046776
# phi_entry: 1.1091188800227763
# phi_exit: 0.7242919310260856
# phi_switch: 1.4494160070420579
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455814737822601
# xi: 0.4150975059791829
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.0124801644088
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855567527702
# income_shock_std: 0.16029470304223975
# taste_shock_scale: 0.9104607556608517
# discount_factor: 0.9128963784041703
# rho: 0.35340187549374
# gamma: [0.56107686 1.13829949 1.68758188 1.58020961]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897604513207605
# kappa2: 0.0017746163396705214
# phi_entry: 1.1091184914518473
# phi_exit: 0.7242916257398747
# phi_switch: 1.4494161113097517
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581685100154
# xi: 0.4150974458528992
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855895239414
# income_shock_std: 0.1602947000716956
# taste_shock_scale: 0.9104607966631543
# discount_factor: 0.9128963762553077
# rho: 0.3534018664485146
# gamma: [0.56107687 1.13829974 1.68758198 1.58020957]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01289760569913859
# kappa2: 0.001774616302033291
# phi_entry: 1.1091182950787313
# phi_exit: 0.7242917066897314
# phi_switch: 1.4494159003887719
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581714531411
# xi: 0.4150974062552276
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855564080703
# income_shock_std: 0.16029469841548238
# taste_shock_scale: 0.9104607600997758
# discount_factor: 0.9128963809116359
# rho: 0.3534018437664541
# gamma: [0.56107677 1.13829953 1.68758199 1.58020972]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01289760128882839
# kappa2: 0.0017746164624663013
# phi_entry: 1.1091186333478873
# phi_exit: 0.7242916106920299
# phi_switch: 1.449416086366207
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455816468449346
# xi: 0.4150974937437395
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855787785584
# income_shock_std: 0.1602947022385703
# taste_shock_scale: 0.9104607567511617
# discount_factor: 0.9128963871442073
# rho: 0.3534018696883494
# gamma: [0.56107681 1.13829971 1.68758199 1.58020969]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897602105729074
# kappa2: 0.0017746163783109116
# phi_entry: 1.1091185005634265
# phi_exit: 0.7242916063949894
# phi_switch: 1.4494159933304922
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455816382667813
# xi: 0.4150974593897434
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855400475721
# income_shock_std: 0.16029469929739593
# taste_shock_scale: 0.9104607024955762
# discount_factor: 0.9128963983299314
# rho: 0.35340186128586737
# gamma: [0.56107683 1.13829955 1.68758195 1.58020974]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897601426654033
# kappa2: 0.0017746163136664892
# phi_entry: 1.1091187671788392
# phi_exit: 0.7242914695745328
# phi_switch: 1.4494160727183387
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581772791362
# xi: 0.4150974734632469
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000577785614185057
# income_shock_std: 0.16029470930648276
# taste_shock_scale: 0.9104607607636768
# discount_factor: 0.9128963753719366
# rho: 0.35340189307664716
# gamma: [0.56107683 1.1382996  1.68758188 1.58020963]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897605899501027
# kappa2: 0.001774616341246521
# phi_entry: 1.1091183487876137
# phi_exit: 0.7242915487681282
# phi_switch: 1.4494160934779639
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455815739971663
# xi: 0.41509744494935175
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856380955963
# income_shock_std: 0.1602947113712131
# taste_shock_scale: 0.9104607735432839
# discount_factor: 0.9128963817623108
# rho: 0.3534018774983746
# gamma: [0.5610768  1.13829966 1.68758192 1.58020966]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897605500701735
# kappa2: 0.0017746163334707563
# phi_entry: 1.1091183264008686
# phi_exit: 0.7242915766640605
# phi_switch: 1.4494161087716568
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455814528960591
# xi: 0.4150974512804193
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000577785668699783
# income_shock_std: 0.16029471473649884
# taste_shock_scale: 0.9104607322541611
# discount_factor: 0.9128963704603036
# rho: 0.35340191757112893
# gamma: [0.56107683 1.13829967 1.68758186 1.58020964]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897606963558782
# kappa2: 0.001774616345294698
# phi_entry: 1.1091182911657484
# phi_exit: 0.7242914862515848
# phi_switch: 1.449416094590071
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455815352214068
# xi: 0.41509742995905596
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855307918
# income_shock_std: 0.16029469442470934
# taste_shock_scale: 0.910460805581141
# discount_factor: 0.9128963806981782
# rho: 0.353401844397908
# gamma: [0.56107682 1.13829972 1.68758205 1.58020958]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.0128976046911832
# kappa2: 0.0017746162914398036
# phi_entry: 1.1091184634167994
# phi_exit: 0.7242917512992845
# phi_switch: 1.4494158065027325
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581889354118
# xi: 0.4150974094554032
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856176529808
# income_shock_std: 0.16029470548122365
# taste_shock_scale: 0.9104607942180141
# discount_factor: 0.9128963939350148
# rho: 0.353401872240778
# gamma: [0.56107677 1.13829964 1.68758194 1.58020961]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897604879985322
# kappa2: 0.0017746163242358727
# phi_entry: 1.1091183714415733
# phi_exit: 0.724291666581948
# phi_switch: 1.4494160342418967
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455816067586158
# xi: 0.4150974355416912
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.00057778564553441
# income_shock_std: 0.1602947050482029
# taste_shock_scale: 0.9104607919438638
# discount_factor: 0.9128963991459915
# rho: 0.35340184939576735
# gamma: [0.56107676 1.13829971 1.68758193 1.58020971]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897602646530561
# kappa2: 0.0017746163243008669
# phi_entry: 1.109118538603394
# phi_exit: 0.7242916452723006
# phi_switch: 1.4494160250809827
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455815525661627
# xi: 0.415097443929208
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856689893489
# income_shock_std: 0.1602947119429564
# taste_shock_scale: 0.9104606776994848
# discount_factor: 0.9128963672404594
# rho: 0.3534019493149763
# gamma: [0.56107676 1.13829939 1.68758189 1.58020958]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897606332377218
# kappa2: 0.0017746163822427664
# phi_entry: 1.1091184496634219
# phi_exit: 0.7242914285451469
# phi_switch: 1.4494161988363536
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455815304452607
# xi: 0.4150975014595719
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000577785615305659
# income_shock_std: 0.16029471285984587
# taste_shock_scale: 0.9104606698027522
# discount_factor: 0.9128963873204976
# rho: 0.35340193636925293
# gamma: [0.56107679 1.13829936 1.6875819  1.58020961]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897606478319768
# kappa2: 0.001774616458464551
# phi_entry: 1.1091184925567852
# phi_exit: 0.7242913793710788
# phi_switch: 1.4494161622200152
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455816409896747
# xi: 0.4150974816809898
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855917637335
# income_shock_std: 0.16029470548732883
# taste_shock_scale: 0.9104607375926683
# discount_factor: 0.912896392804607
# rho: 0.3534018996092738
# gamma: [0.56107682 1.13829965 1.68758197 1.58020963]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897605854970146
# kappa2: 0.0017746163361411678
# phi_entry: 1.1091183943811753
# phi_exit: 0.7242914971872954
# phi_switch: 1.4494159888735159
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455817721875078
# xi: 0.41509743617376715
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856465171633
# income_shock_std: 0.1602947150055535
# taste_shock_scale: 0.9104607376041732
# discount_factor: 0.9128963796572893
# rho: 0.3534018970646051
# gamma: [0.56107679 1.13829968 1.68758191 1.5802097 ]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897604451281817
# kappa2: 0.0017746164248236551
# phi_entry: 1.1091183495945254
# phi_exit: 0.7242914672913595
# phi_switch: 1.449416160721277
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455814302172135
# xi: 0.4150974674599054
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.000577785569662276
# income_shock_std: 0.160294697262133
# taste_shock_scale: 0.9104607906191471
# discount_factor: 0.9128963520713171
# rho: 0.3534017981892974
# gamma: [0.56107675 1.13829975 1.68758203 1.58020985]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.01289759593718241
# kappa2: 0.001774616413378483
# phi_entry: 1.1091187769082935
# phi_exit: 0.7242917791395088
# phi_switch: 1.4494160841868176
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.2455814409281212
# xi: 0.4150975096016646
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01240635304674
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777856375754448
# income_shock_std: 0.16029471602843223
# taste_shock_scale: 0.9104607019003568
# discount_factor: 0.9128964117998655
# rho: 0.3534019732236551
# gamma: [0.56107687 1.13829947 1.68758183 1.58020945]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897613312462107
# kappa2: 0.0017746163180324469
# phi_entry: 1.1091181044941265
# phi_exit: 0.7242913294520604
# phi_switch: 1.4494160377564873
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.245581813647037
# xi: 0.4150973949605623
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01254456396006
#
# Parameter dictionary used:
# interest_rate: 0.01
# income_shock_mean: 0.0005777855866405683
# income_shock_std: 0.16029470195370782
# taste_shock_scale: 0.9104607684394495
# discount_factor: 0.9128963670034542
# rho: 0.3534018419478868
# gamma: [0.56107678 1.13829968 1.68758198 1.58020975]
# beta0: -7.721101409916507
# beta1: 0.07418311839644703
# beta2: -0.0005894472446704149
# kappa1: 0.012897600281002335
# kappa2: 0.001774616389541974
# phi_entry: 1.1091186088047518
# phi_exit: 0.7242916667176467
# phi_switch: 1.4494160725792349
# alpha1: 0.000417
# alpha2: 0.099277
# b_scale: 1.24558153410785
# xi: 0.415097480941389
# eta_edu: 0.43848
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Crit value: 210.01232932613087
#
# Optimization terminated successfully.
#          Current function value: 210.012256
#          Iterations: 535
#          Function evaluations: 950
# Optimization result:
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 210.0122555147688
#              x: [ 5.778e-04  1.603e-01 ...  1.246e+00  4.151e-01]
#            nit: 535
#           nfev: 950
#  final_simplex: (array([[ 5.778e-04,  1.603e-01, ...,  1.246e+00,
#                          4.151e-01],
#                        [ 5.778e-04,  1.603e-01, ...,  1.246e+00,
#                          4.151e-01],
#                        ...,
#                        [ 5.778e-04,  1.603e-01, ...,  1.246e+00,
#                          4.151e-01],
#                        [ 5.778e-04,  1.603e-01, ...,  1.246e+00,
#                          4.151e-01]], shape=(17, 16)), array([ 2.100e+02,  2.100e+02, ...,  2.100e+02,  2.100e+02],
#                       shape=(17,)))

# %% [markdown]
# ### Save the estimation results

# %%
# Rebuild optimized parameter dictionary using the same mapping
# as the criterion function.
params_hat = theta_to_params(result.x, base_params=base_params)

# Make absolutely sure legacy names are gone
params_hat.pop("sigma", None)
params_hat.pop("beta", None)
params_hat.pop("phi", None)

# Convert gamma from JAX array to NumPy array for cleaner saving    
params_hat["gamma"] = np.asarray(params_hat["gamma"])

# Save params dict as a .txt file
params_df = pd.DataFrame.from_dict(
    params_hat,
    orient="index",
    columns=["value"],
)

params_df.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_{version}.txt",
    sep="\t",
)

params_df
# Out:
#                                                                value
# interest_rate                                                   0.01
# income_shock_mean                                           0.000578
# income_shock_std                                            0.160295
# taste_shock_scale                                           0.910461
# discount_factor                                             0.912896
# rho                                                         0.353402
# gamma              [0.5610768320157882, 1.1382996630639015, 1.687...
# beta0                                                      -7.721101
# beta1                                                       0.074183
# beta2                                                      -0.000589
# kappa1                                                      0.012898
# kappa2                                                      0.001775
# phi_entry                                                   1.109118
# phi_exit                                                    0.724291
# phi_switch                                                  1.449416
# alpha1                                                      0.000417
# alpha2                                                      0.099277
# b_scale                                                     1.245582
# xi                                                          0.415097
# eta_edu                                                      0.43848

# %% [markdown]
# ## Plots

# %%
plot_labels = {
    "avg_wealth": "Average Wealth",
    "hours_0": "Unemployed",
    "hours_1": "Below 10 hours",
    "hours_2": "10-20 hours",
    "hours_3": "20-30 hours",
    "hours_4": "Above 30 hours",
    "avg_hours": "Average Hours",
    "prob_work": "Employment Rate",
    "avg_wage": "Average Wage",
    "avg_experience": "Average Experience",
    "work_work": "Work to Work Transition Rate",
    "nowork_nowork": "No Work to No Work Transition Rate",
}

plot_scales = {
    "avg_wealth": 100_000,
    "avg_wage": 100_000,
}

# %% [markdown]
# ### Solve, simulate and plot final model

# %%
params = load_params_txt(pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_phi_udd3.txt")
params["gamma"] = jnp.asarray(params["gamma"])

# %%
model_solved = model.solve(params)
sim = model_solved.simulate(
    states_initial=states_initial,
    seed=seed,
)

edu = df_edu.copy().loc[df_edu.age <= 75]       # empirical
# moments_sim = compute_simulation_moments_with_ci(sim, start_age, hours_map)  # Call the function
moments_sim = compute_simulation_moments_with_ci(sim, start_age, hours_map)  # Call the function

# Ensure moments_sim.age is a pandas Series before filtering
moments_sim = moments_sim.loc[pd.Series(moments_sim.age) <= 75]  # Filter simulated + CIs
# scale avg_wealth by 100_000

# print plots
plot_empirical_vs_simulated_with_ci(
    edu = edu,
    moments_sim = moments_sim,
    out_subfolder="edu3_phi_specification",
    var_labels=plot_labels,
    var_scales=plot_scales,
    ylims={"avg_wealth": (0, 3_000_000), "avg_hours": (0, 2_000), "prob_work": (0, 1), "hours_0": (0, 1), "hours_1": (0, 0.2), "hours_2": (0, 0.2), "hours_3": (0, 0.3), "hours_4": (0, 1), "avg_wage": (0,500) },
)
# Out:
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\prob_work_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\hours_0_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\hours_1_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\hours_2_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\hours_3_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\hours_4_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\avg_wealth_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\work_work_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\nowork_nowork_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\avg_experience_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\avg_labor_income_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\avg_wage_over_age.png
# Saved C:\Users\Nashw\Studiet\polit\2. Semester\DynamicProgramming\Thesis\dp_termpaper\4. Results\plots\simulation\edu3_phi_specification\avg_hours_over_age.png
