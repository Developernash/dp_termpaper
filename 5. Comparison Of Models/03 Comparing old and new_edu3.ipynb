# %% [markdown]
# # Comparing the Criterion Value
# ## Original Model vs Phi Specified Model
# ### Education Level 3

# %% [markdown]
# ## Dependencies, Packages & Roots

# %% [markdown]
# ### Magics

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Project Paths

# %%
from pathlib import Path
import sys
import importlib

# Change this depending on notebook location:
# 0 = notebook is 1 folder inside project root, e.g. dp_termpaper/edu1
# 1 = notebook is 2 folders inside project root, e.g. dp_termpaper/data/moments
# 2 = notebook is 3 folders inside project root
amount_of_levels = 0

DIR = Path.cwd().resolve().parents[amount_of_levels]

if str(DIR) not in sys.path:
    sys.path.insert(0, str(DIR))

import project_paths as pp
from project_imports import *

importlib.reload(pp)
jax.config.update("jax_enable_x64", True)

# %% [markdown]
# ## Load Data

# %%
###############################################################
#### Define which education level you want to estimate for ####
###############################################################

# education_level_file = pp.MOMENTS_DIR / "moments_udd1.txt"
# education_level_file = pp.MOMENTS_DIR / "moments_udd2.txt"
education_level_file = pp.MOMENTS_DIR / "moments_udd3.txt"

version = "phi_udd3" # for saving results, change this when you change the specification

MORTALITY = pp.DATA_DIR / "mortality.xlsx"

beta0, beta1, beta2 = np.loadtxt(pp.FIRST_STAGE_RESULTS_DIR / "wage_params_udd3_ols.txt")

# %%
# Read CSV
df_edu = pd.read_csv(education_level_file)
# read mortality and discard seoncd and third column
df_mort = pd.read_excel(MORTALITY, sheet_name="DOD", usecols=[0, 3])

# 2) standardize colomn name and remove _FREQ_ column
# Iterate over DataFrames (if there are multiple DataFrames to process)
for data_frame in [df_edu]:
    # Rename ALDER → age
    if "ALDER" in data_frame.columns:
        data_frame.rename(columns={"ALDER": "age"}, inplace=True)
    # Remove _FREQ_-column if it exists
    # if "_FREQ_" in data_frame.columns:
    #     data_frame.drop(columns=["_FREQ_"], inplace=True)
# drop var_wage, skew_wage and pens
df_edu.drop(columns=["var_wage", "skew_wage", "pens"], inplace=True)
# df_edu

# %% [markdown]
# # ====================================================================================================================

# %% [markdown]
# ## Options for model - Choices and states

# %%
n_periods = 55
labour_choices = np.arange(5) # 5 choices
alpha1, alpha2 = np.loadtxt(pp.STRUCTURAL_RESULTS_DIR/ "mortality_params.txt")

model_config = {
    "n_periods": n_periods,
    "choices": labour_choices, # 5 choices
    "n_quad_points": 5,
    "continuous_states": {
        "assets_end_of_period": np.linspace(0, 50, 20),
        "experience": jnp.linspace(0, 1, 5).astype(float) # 1 experince grid point, if experience can only go up by a year - more points if it is a fraction based on hours worked
        },
    "stochastic_states": {
        "survival": [0, 1],
    }
    }

model_specs = {
    "choices": labour_choices, # 5 choices
    "n_periods": n_periods,
    "labour_choices": labour_choices, # 5 choices
    "hours": jnp.array([0,250,750,1300,1900]), #list 
    "max_hours": 1900,
    "start_age": 30,
    "tax_threshold1": 0.480,
    "tax_threshold2": 5.698,
    "tax_base_rate": 0.38,
    "tax_top_rate": 0.5,
    "retirement_age": 67,
    "oap_base_amount": 0.80328,
    "oap_max_supplement": 0.92940,
    "supp_threshold": 0.79300,
    "oap_threshold": 3.3592,
    "supp_reduction_rate": 0.309,
    "oap_reduction_rate": 0.3,
    "alpha1": alpha1, # independently estimated parameter for survival probability
    "alpha2": alpha2,  # independently estimated parameter for survival probability
    "max_init_experience": 5,
    "max_ret_period": 45, # Age 75
    "min_ret_period": 30, # Age 60
}
stochastic_states_transitions = {
    "survival": prob_survival
}

# %% [markdown]
# ### Initial values for simulating.

# %%
# Select number of individuals for simulation
#Debug level
n_individuals = 10000

# Optimal level
# n_individuals = 250000

seed = 132
key = jax.random.PRNGKey(0)
n = n_individuals       

# hours mapping for simulation
hours_map = {0: 0, 1: 250, 2: 750, 3: 1300, 4: 1900}

#age for simulation
start_age = model_specs["start_age"] 

# distribution of initial choices
labels = jnp.array([0, 1, 2, 3, 4], dtype=jnp.int32)
probs  = jnp.array([0.259155, 0.118310, 0.108099, 0.108451, 0.405986])  # sums to 1.0

lagged_choice = jax.random.choice(
    key,
    a       = labels,
    shape   = (n,),
    p       = probs,
    replace = True
)

# set initial states for each individual
states_initial = {
    "period": jnp.zeros(n_individuals, dtype=jnp.int32),      # Every individual starts at period 0 (age 30)
    "lagged_choice": lagged_choice,  # Every individual starts with choice 3 (work fulltime)
    "experience": jnp.full(n_individuals, 1).astype(float),  # Every individual starts with 5 years of experience
    "survival": jnp.ones(n_individuals, dtype=jnp.int32), # Every individual starts with 1 (alive)
    "assets_begin_of_period": jnp.full(n_individuals, 0.505047) # Every individual starts with 59k wealth - to be adjusted based on the actual moments
}

# %% [markdown]
# ### Define Criterion function for simulating across seeds

# %%
def criterion(model_solved, seed=seed):
    
    keep_cols = ["hours_0", "hours_1","hours_2","hours_3","hours_4", "work_work", "nowork_nowork"]

    # Simulate model
    sim = model_solved.simulate(
        states_initial=states_initial,
        seed=seed,
    )

    # Compute simulated moments - returning a dataframe similar to the actual data
    sim_moments = compute_simulation_moments(sim, start_age, hours_map)
    empirical_moms = df_edu.copy()  # Your empirical moments DataFrame

    # Drop the "pens" column from both simulated and empirical moments if present
    if "pens" in sim_moments.columns:
        sim_moments = sim_moments.drop(columns=["pens"])
    if "pens" in empirical_moms.columns:
        empirical_moms = empirical_moms.drop(columns=["pens"])

    # Select only the columns of interest for the moments comparison
    sim_moments = sim_moments[keep_cols]
    empirical_moms = empirical_moms[keep_cols]

    # Convert DataFrames to numpy arrays.
    # They should have the same shape, e.g., (num_ages, num_moments)
    sim_vals = sim_moments.to_numpy()
    emp_vals = empirical_moms.to_numpy()

    # Debug-print shapes so that we can ensure they are the same shape
    print("Simulated moments shape:", sim_vals.shape)
    print("Empirical moments shape:", emp_vals.shape)

    # Compute the difference between simulated and empirical moments.
    # diff will have shape (num_ages, num_moments)
    diff = sim_vals - emp_vals

    # Now, for each moment (each column), compute the sample variance of the empirical moment
    ## Should be computed through the data before moments i think
    emp_var = np.nanvar(emp_vals, axis=0, ddof=1)  # Sample variance
    # compute simulated moments variance
    sim_var = np.nanvar(sim_vals, axis=0, ddof=1)  # Sample variance

    total_var = emp_var + sim_var

    # Set a small epsilon to avoid division by zero.
    epsilon = 1e-10

    # The weight for each moment is defined as 1/(variance + epsilon).
    weights = 1.0 / (emp_var + epsilon)
  
    # Instead of forming a full weighting matrix, we can compute the objective by summing over moment columns.
    # For each moment i, compute the sum of squared differences over ages, multiplied by its weight.
    # as in crit = diff^T * W * diff
    # where W is a diagonal matrix with weights on the diagonal.
    # The crit_val is the sum of the weighted squared differences.
    
    num_moments = diff.shape[1]
    crit_val = 0.0
    for i in range(num_moments):
        crit_val += weights[i] * np.nansum(diff[:, i] ** 2)
    
    print("Seed:", seed)
    print("Crit value:", crit_val)
    return float(crit_val)

# %% [markdown]
# ## New model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params = load_params_txt(pp.STRUCTURAL_RESULTS_DIR / f"optimized_params_phi_udd3.txt")
params["gamma"] = jnp.asarray(params["gamma"])

# %%
new_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
new_model_solved = new_model.solve(params)
new_model.validate_exogenous(params)
# Out:
# True

# %%
n_sim = 100

# %% [markdown]
# ### Running the criterion value across 100 seeds for my model

# %%
new_model_results = []
rng = np.random.default_rng()

for i in range(n_sim):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(new_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    new_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })


new_model_crit_table = pd.DataFrame(new_model_results)

new_model_crit_table

new_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "new_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1327206221
# Crit value: 207.94335338058428
# Run 001 | Seed: 1327206221 | Criterion value: 207.943353
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1769682239
# Crit value: 215.0332250421343
# Run 002 | Seed: 1769682239 | Criterion value: 215.033225
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1840948590
# Crit value: 206.08826448918074
# Run 003 | Seed: 1840948590 | Criterion value: 206.088264
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1588400627
# Crit value: 210.8045803311722
# Run 004 | Seed: 1588400627 | Criterion value: 210.804580
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1797798732
# Crit value: 212.90791735881683
# Run 005 | Seed: 1797798732 | Criterion value: 212.907917
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1396631686
# Crit value: 224.85720454466983
# Run 006 | Seed: 1396631686 | Criterion value: 224.857205
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 335798008
# Crit value: 213.76331395139272
# Run 007 | Seed: 335798008 | Criterion value: 213.763314
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1507710951
# Crit value: 208.6022592133477
# Run 008 | Seed: 1507710951 | Criterion value: 208.602259
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2125945163
# Crit value: 214.1341599343201
# Run 009 | Seed: 2125945163 | Criterion value: 214.134160
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 811461786
# Crit value: 223.66462280740475
# Run 010 | Seed: 811461786 | Criterion value: 223.664623
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1311386191
# Crit value: 217.12574677031148
# Run 011 | Seed: 1311386191 | Criterion value: 217.125747
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1020409829
# Crit value: 206.4888798923082
# Run 012 | Seed: 1020409829 | Criterion value: 206.488880
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 362734174
# Crit value: 209.7649293659961
# Run 013 | Seed: 362734174 | Criterion value: 209.764929
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 431449164
# Crit value: 216.4888408130195
# Run 014 | Seed: 431449164 | Criterion value: 216.488841
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 62136402
# Crit value: 210.41601458355095
# Run 015 | Seed: 62136402 | Criterion value: 210.416015
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 784513461
# Crit value: 206.45293913886462
# Run 016 | Seed: 784513461 | Criterion value: 206.452939
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 813652731
# Crit value: 208.75305100554874
# Run 017 | Seed: 813652731 | Criterion value: 208.753051
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2054434927
# Crit value: 214.4304088454768
# Run 018 | Seed: 2054434927 | Criterion value: 214.430409
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 138933458
# Crit value: 211.2906901003019
# Run 019 | Seed: 138933458 | Criterion value: 211.290690
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 600431518
# Crit value: 221.33231181810788
# Run 051 | Seed: 600431518 | Criterion value: 221.332312
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 424222648
# Crit value: 215.90765461334135
# Run 052 | Seed: 424222648 | Criterion value: 215.907655
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1665017299
# Crit value: 215.53720901117424
# Run 053 | Seed: 1665017299 | Criterion value: 215.537209
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1940978406
# Crit value: 210.82422901640533
# Run 054 | Seed: 1940978406 | Criterion value: 210.824229
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1887934295
# Crit value: 216.68878568441193
# Run 055 | Seed: 1887934295 | Criterion value: 216.688786
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1831797031
# Crit value: 207.54292324968324
# Run 056 | Seed: 1831797031 | Criterion value: 207.542923
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 209179566
# Crit value: 223.19337521438453
# Run 057 | Seed: 209179566 | Criterion value: 223.193375
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1927025579
# Crit value: 214.12523154692408
# Run 058 | Seed: 1927025579 | Criterion value: 214.125232
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1211282313
# Crit value: 206.1375159888136
# Run 059 | Seed: 1211282313 | Criterion value: 206.137516
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 95390576
# Crit value: 217.0949270909764
# Run 060 | Seed: 95390576 | Criterion value: 217.094927
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1616356668
# Crit value: 208.18858546650287
# Run 061 | Seed: 1616356668 | Criterion value: 208.188585
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1215141426
# Crit value: 214.85002138552468
# Run 062 | Seed: 1215141426 | Criterion value: 214.850021
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1722962560
# Crit value: 221.5764454840274
# Run 063 | Seed: 1722962560 | Criterion value: 221.576445
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1430001260
# Crit value: 213.18900515874483
# Run 064 | Seed: 1430001260 | Criterion value: 213.189005
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 378342314
# Crit value: 223.920220444788
# Run 065 | Seed: 378342314 | Criterion value: 223.920220
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 943601322
# Crit value: 219.90850872629215
# Run 066 | Seed: 943601322 | Criterion value: 219.908509
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2125802859
# Crit value: 208.7444483784009
# Run 067 | Seed: 2125802859 | Criterion value: 208.744448
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1708212601
# Crit value: 211.7712591169395
# Run 068 | Seed: 1708212601 | Criterion value: 211.771259
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1035049073
# Crit value: 212.24072133522768
# Run 069 | Seed: 1035049073 | Criterion value: 212.240721
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 590160222
# Crit value: 215.5316808994448
# Run 070 | Seed: 590160222 | Criterion value: 215.531681
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 569042500
# Crit value: 213.79520523153332
# Run 071 | Seed: 569042500 | Criterion value: 213.795205
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1965304572
# Crit value: 208.9335946565178
# Run 072 | Seed: 1965304572 | Criterion value: 208.933595
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 290619413
# Crit value: 213.58627696119942
# Run 073 | Seed: 290619413 | Criterion value: 213.586277
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2131100906
# Crit value: 210.41352282016751
# Run 074 | Seed: 2131100906 | Criterion value: 210.413523
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 527878133
# Crit value: 207.87701556487593
# Run 075 | Seed: 527878133 | Criterion value: 207.877016
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1183850258
# Crit value: 224.77140811956576
# Run 076 | Seed: 1183850258 | Criterion value: 224.771408
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 236988414
# Crit value: 206.68223705068885
# Run 077 | Seed: 236988414 | Criterion value: 206.682237
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1392127606
# Crit value: 210.97938058807688
# Run 078 | Seed: 1392127606 | Criterion value: 210.979381
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 230790528
# Crit value: 222.3636082290491
# Run 079 | Seed: 230790528 | Criterion value: 222.363608
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 366311399
# Crit value: 216.09099046513586
# Run 080 | Seed: 366311399 | Criterion value: 216.090990
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1263553572
# Crit value: 204.87277315239098
# Run 081 | Seed: 1263553572 | Criterion value: 204.872773
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 813254970
# Crit value: 214.37000364015577
# Run 082 | Seed: 813254970 | Criterion value: 214.370004
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 680183037
# Crit value: 208.11295120223855
# Run 083 | Seed: 680183037 | Criterion value: 208.112951
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1232455237
# Crit value: 201.42487845368714
# Run 084 | Seed: 1232455237 | Criterion value: 201.424878
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1489974029
# Crit value: 226.3963318111741
# Run 085 | Seed: 1489974029 | Criterion value: 226.396332
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 859478253
# Crit value: 212.8467871329235
# Run 086 | Seed: 859478253 | Criterion value: 212.846787
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 923907561
# Crit value: 211.41793474762832
# Run 087 | Seed: 923907561 | Criterion value: 211.417935
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 51160650
# Crit value: 215.60516195205847
# Run 088 | Seed: 51160650 | Criterion value: 215.605162
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1409331777
# Crit value: 211.66941451314563
# Run 089 | Seed: 1409331777 | Criterion value: 211.669415
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1968473912
# Crit value: 214.85147566032134
# Run 090 | Seed: 1968473912 | Criterion value: 214.851476
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1583698036
# Crit value: 211.1986301898179
# Run 091 | Seed: 1583698036 | Criterion value: 211.198630
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1358961416
# Crit value: 221.2998960137052
# Run 092 | Seed: 1358961416 | Criterion value: 221.299896
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 364513569
# Crit value: 207.16023282691336
# Run 093 | Seed: 364513569 | Criterion value: 207.160233
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 337638287
# Crit value: 212.24164947578348
# Run 094 | Seed: 337638287 | Criterion value: 212.241649
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 187332545
# Crit value: 216.94220859572843
# Run 095 | Seed: 187332545 | Criterion value: 216.942209
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 415968687
# Crit value: 216.56301847431126
# Run 096 | Seed: 415968687 | Criterion value: 216.563018
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 779026647
# Crit value: 217.92376293918235
# Run 097 | Seed: 779026647 | Criterion value: 217.923763
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 478820552
# Crit value: 217.54610503589424
# Run 098 | Seed: 478820552 | Criterion value: 217.546105
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 296780198
# Crit value: 213.19180100946886
# Run 099 | Seed: 296780198 | Criterion value: 213.191801
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1844052955
# Crit value: 209.1800638935799
# Run 100 | Seed: 1844052955 | Criterion value: 209.180064

# %% [markdown]
# ## Old model

# %% [markdown]
# ### Load params, solve model and simulate juts once

# %%
params_old = {
    "interest_rate": 0.01,
    "income_shock_mean": 0.0,
    "income_shock_std": 0.2,
    "taste_shock_scale": 2.4,
    "discount_factor": 0.9862761291459945,
    "rho": 0.4546033105783697,
    "gamma": jnp.asarray([0.6436928, 1.3013253, 1.95873805, 1.65679825]),
    "kappa1": 0.009068366633740818,
    "kappa2": 0.001434998756969184,
    "phi": 5.711828977972858,
    "b_scale": 0.5496627563003196,
    "xi": 0.008433463067153925,
    "eta_edu": 1.10158,
    "alpha1": 0.000417,
    "alpha2": 0.099277,
    "beta0": -7.7211014099165185,
    "beta1": 0.07418311839644762,
    "beta2": -0.0005894472446704196
}

# %%
def flow_util(consumption, choice, params, period, model_specs, lagged_choice):
    # Utility parameter
    rho = params["rho"]

    # Disutility parameters
    age = (model_specs["start_age"] + period).astype(float)
    gamma = params["gamma"][choice - 1]  # remove the first element

    ##############################################
    ########## Disutility of working #############
    ##############################################
    working = choice > 0  # 1 if choice is working, 0 if not
    # -------  Zero disutility from working if unemployed

    # Age component of disutility
    age_linear = jnp.where(age >= 55, params["kappa1"] * (age - 55), 0.0)
    age_quadratic = jnp.where(age >= 55, params["kappa2"] * (age - 55) ** 2, 0.0)   
    # + age_linear

    # estimate total disutility
    disutil_0 = working * (1.0 + age_linear + age_quadratic) * gamma

    # No disutility from working, if you dont work.
    disutil = jnp.where(working, disutil_0, 0.0)  # if working == 0, disutility = 0

    ##############################################
    ############# Transaction costs  #############
    ##############################################

    # transition cost when going from working to unemployed, and vice versa
    trans_cost = jnp.where(
        choice != lagged_choice, params["phi"], 0.0
    )

    # Utility for agents that are alive.
    u = (
        ((consumption ** (1 - rho)) - 1) / (1 - rho) - disutil - trans_cost
    ) 

    return u


def marginal_utility(consumption, params):
    rho = params["rho"]
    u_prime = consumption ** (-rho)
    return u_prime


def inverse_marginal_utility(marginal_utility, params):
    rho = params["rho"]
    return marginal_utility ** (-1 / rho)


utility_functions = {
    "utility": flow_util,
    "inverse_marginal_utility": inverse_marginal_utility,
    "marginal_utility": marginal_utility,
}

# %%
old_model = dcegm.setup_model(
    model_config=model_config,
    model_specs=model_specs,
    utility_functions=utility_functions,
    utility_functions_final_period=final_period_utility,
    budget_constraint=budget_dcegm_initial,
    state_space_functions=create_state_space_function_dict(),
    stochastic_states_transitions=stochastic_states_transitions,
)
# Out:
# Starting state space creation
# State space created.
#
# Starting state-choice space creation and child state mapping.
# State, state-choice and child state mapping created.
#
# Start creating batches for the model.
# The batch size of the backwards induction is  25
# Model setup complete.

# %%
old_model_solved = old_model.solve(params_old)
old_model.validate_exogenous(params_old)
# Out:
# True

# %% [markdown]
# ### Running the criterion value across 100 seeds for Larsen model

# %%
old_model_results = []
rng = np.random.default_rng()

for i in range(n_sim):
    seed = int(rng.integers(0, 2**31 - 1))
    crit_val = criterion(old_model_solved, seed)

    print(f"Run {i+1:03d} | Seed: {seed} | Criterion value: {crit_val:.6f}")

    old_model_results.append({
        "seed": seed,
        "criterion_value": crit_val,
    })

old_model_crit_table = pd.DataFrame(old_model_results)

old_model_crit_table

old_model_crit_table.to_csv(
    pp.STRUCTURAL_RESULTS_DIR / "old_model_criterion_by_seed.csv",
    index=False,
)
# Out:
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 166841775
# Crit value: 290.03847998125735
# Run 001 | Seed: 166841775 | Criterion value: 290.038480
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 875338567
# Crit value: 291.9672690965416
# Run 002 | Seed: 875338567 | Criterion value: 291.967269
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1308792914
# Crit value: 298.4776185560405
# Run 003 | Seed: 1308792914 | Criterion value: 298.477619
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1001343892
# Crit value: 303.4398843002536
# Run 004 | Seed: 1001343892 | Criterion value: 303.439884
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1905834258
# Crit value: 287.6967110012819
# Run 005 | Seed: 1905834258 | Criterion value: 287.696711
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1048368462
# Crit value: 295.3560998826333
# Run 006 | Seed: 1048368462 | Criterion value: 295.356100
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1487912728
# Crit value: 304.77781854695195
# Run 007 | Seed: 1487912728 | Criterion value: 304.777819
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 263984815
# Crit value: 301.33984056560905
# Run 008 | Seed: 263984815 | Criterion value: 301.339841
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 266767851
# Crit value: 297.7077563185766
# Run 009 | Seed: 266767851 | Criterion value: 297.707756
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2130962605
# Crit value: 295.8844244779181
# Run 010 | Seed: 2130962605 | Criterion value: 295.884424
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 359049019
# Crit value: 294.35660393776675
# Run 011 | Seed: 359049019 | Criterion value: 294.356604
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 443711417
# Crit value: 299.5075620698531
# Run 012 | Seed: 443711417 | Criterion value: 299.507562
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1065311486
# Crit value: 305.34790879815154
# Run 013 | Seed: 1065311486 | Criterion value: 305.347909
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 225445229
# Crit value: 291.01895042723515
# Run 014 | Seed: 225445229 | Criterion value: 291.018950
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 564892704
# Crit value: 293.565283269646
# Run 015 | Seed: 564892704 | Criterion value: 293.565283
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 677609866
# Crit value: 295.82889414696314
# Run 016 | Seed: 677609866 | Criterion value: 295.828894
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2108021022
# Crit value: 301.83428443429716
# Run 017 | Seed: 2108021022 | Criterion value: 301.834284
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1088923832
# Crit value: 301.8172304581744
# Run 018 | Seed: 1088923832 | Criterion value: 301.817230
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1335784100
# Crit value: 294.01664691291666
# Run 019 | Seed: 1335784100 | Criterion value: 294.016647
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 937006953
# Crit value: 294.9689535244336
# Run 051 | Seed: 937006953 | Criterion value: 294.968954
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1351735162
# Crit value: 291.79946898099723
# Run 052 | Seed: 1351735162 | Criterion value: 291.799469
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 929580383
# Crit value: 291.91231856414964
# Run 053 | Seed: 929580383 | Criterion value: 291.912319
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 774374129
# Crit value: 294.90682724239406
# Run 054 | Seed: 774374129 | Criterion value: 294.906827
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1996022693
# Crit value: 305.8253014118432
# Run 055 | Seed: 1996022693 | Criterion value: 305.825301
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 141891248
# Crit value: 300.21834980444265
# Run 056 | Seed: 141891248 | Criterion value: 300.218350
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1688754378
# Crit value: 296.90608565969336
# Run 057 | Seed: 1688754378 | Criterion value: 296.906086
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1942593617
# Crit value: 284.2788094875457
# Run 058 | Seed: 1942593617 | Criterion value: 284.278809
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1250822976
# Crit value: 293.71012115307883
# Run 059 | Seed: 1250822976 | Criterion value: 293.710121
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 819480537
# Crit value: 289.61811142465865
# Run 060 | Seed: 819480537 | Criterion value: 289.618111
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 193857879
# Crit value: 297.9696529165272
# Run 061 | Seed: 193857879 | Criterion value: 297.969653
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1924870122
# Crit value: 291.91960643180937
# Run 062 | Seed: 1924870122 | Criterion value: 291.919606
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 838891954
# Crit value: 304.74231373899806
# Run 063 | Seed: 838891954 | Criterion value: 304.742314
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 626082457
# Crit value: 300.235185791611
# Run 064 | Seed: 626082457 | Criterion value: 300.235186
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1794063638
# Crit value: 280.24228791326476
# Run 065 | Seed: 1794063638 | Criterion value: 280.242288
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1224312043
# Crit value: 293.007162653105
# Run 066 | Seed: 1224312043 | Criterion value: 293.007163
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1842713595
# Crit value: 302.66510561269956
# Run 067 | Seed: 1842713595 | Criterion value: 302.665106
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 50341220
# Crit value: 299.96194279152235
# Run 068 | Seed: 50341220 | Criterion value: 299.961943
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1673475275
# Crit value: 292.18108979827645
# Run 069 | Seed: 1673475275 | Criterion value: 292.181090
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 963745147
# Crit value: 301.48125300519814
# Run 070 | Seed: 963745147 | Criterion value: 301.481253
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 524672173
# Crit value: 301.15003680240886
# Run 071 | Seed: 524672173 | Criterion value: 301.150037
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 842350719
# Crit value: 301.71960444486865
# Run 072 | Seed: 842350719 | Criterion value: 301.719604
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1237785246
# Crit value: 305.45574703990684
# Run 073 | Seed: 1237785246 | Criterion value: 305.455747
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1825476142
# Crit value: 299.260748389451
# Run 074 | Seed: 1825476142 | Criterion value: 299.260748
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1841750102
# Crit value: 294.4792199505307
# Run 075 | Seed: 1841750102 | Criterion value: 294.479220
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1015853885
# Crit value: 311.4818862587948
# Run 076 | Seed: 1015853885 | Criterion value: 311.481886
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 882836705
# Crit value: 300.32355349589903
# Run 077 | Seed: 882836705 | Criterion value: 300.323553
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2049452414
# Crit value: 302.8957507568839
# Run 078 | Seed: 2049452414 | Criterion value: 302.895751
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2005648244
# Crit value: 288.7874309496747
# Run 079 | Seed: 2005648244 | Criterion value: 288.787431
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 189781176
# Crit value: 294.3763342200172
# Run 080 | Seed: 189781176 | Criterion value: 294.376334
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 264328801
# Crit value: 298.64957473401233
# Run 081 | Seed: 264328801 | Criterion value: 298.649575
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1206253847
# Crit value: 292.07959395165665
# Run 082 | Seed: 1206253847 | Criterion value: 292.079594
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1820841838
# Crit value: 286.292304775889
# Run 083 | Seed: 1820841838 | Criterion value: 286.292305
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1404298097
# Crit value: 296.40062396316216
# Run 084 | Seed: 1404298097 | Criterion value: 296.400624
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1884610223
# Crit value: 291.6095681803189
# Run 085 | Seed: 1884610223 | Criterion value: 291.609568
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2086082352
# Crit value: 309.4390515015574
# Run 086 | Seed: 2086082352 | Criterion value: 309.439052
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 2052303776
# Crit value: 294.62655981188885
# Run 087 | Seed: 2052303776 | Criterion value: 294.626560
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1012650233
# Crit value: 297.551747194338
# Run 088 | Seed: 1012650233 | Criterion value: 297.551747
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1107772967
# Crit value: 285.54483296066746
# Run 089 | Seed: 1107772967 | Criterion value: 285.544833
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 299910048
# Crit value: 291.0848214250952
# Run 090 | Seed: 299910048 | Criterion value: 291.084821
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1257982070
# Crit value: 294.05894904543027
# Run 091 | Seed: 1257982070 | Criterion value: 294.058949
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 599378364
# Crit value: 306.11308556914764
# Run 092 | Seed: 599378364 | Criterion value: 306.113086
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1183273106
# Crit value: 297.09979172090846
# Run 093 | Seed: 1183273106 | Criterion value: 297.099792
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1453696234
# Crit value: 302.8463586607884
# Run 094 | Seed: 1453696234 | Criterion value: 302.846359
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1745060694
# Crit value: 292.86784961543975
# Run 095 | Seed: 1745060694 | Criterion value: 292.867850
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 597727499
# Crit value: 300.50654944294115
# Run 096 | Seed: 597727499 | Criterion value: 300.506549
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1169296214
# Crit value: 296.9428930364801
# Run 097 | Seed: 1169296214 | Criterion value: 296.942893
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 280190398
# Crit value: 300.6425249957942
# Run 098 | Seed: 280190398 | Criterion value: 300.642525
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1275354236
# Crit value: 301.4811849652097
# Run 099 | Seed: 1275354236 | Criterion value: 301.481185
# Simulated moments shape: (55, 7)
# Empirical moments shape: (55, 7)
# Seed: 1162633984
# Crit value: 297.85492028484185
# Run 100 | Seed: 1162633984 | Criterion value: 297.854920

# %% [markdown]
# ### Plot the results from both runs

# %%
import matplotlib.pyplot as plt
import pandas as pd

old_vals = old_model_crit_table["criterion_value"]
new_vals = new_model_crit_table["criterion_value"]

summary_table = pd.DataFrame({
    "model": ["old", "new"],
    "mean": [old_vals.mean(), new_vals.mean()],
    "median": [old_vals.median(), new_vals.median()],
    "std": [old_vals.std(), new_vals.std()],
    "min": [old_vals.min(), new_vals.min()],
    "max": [old_vals.max(), new_vals.max()],
})

summary_table
# Out:
#   model        mean      median       std         min         max
# 0   old  296.860561  296.545340  6.825296  280.242288  321.563616
# 1   new  213.654094  213.239833  5.720744  201.424878  230.189319

# %%
# Save values from old and new model for plotting
np.savez(
    pp.COMP_PLOTS_DIR / f"criterion_values_nb3_{n_sim}sim.npz",
    old_vals=old_vals,
    new_vals=new_vals
)

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    old_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="Old model",
)

plt.hist(
    new_vals,
    bins=20,
    alpha=0.5,
    density=True,
    label="New model",
)

plt.axvline(old_vals.mean(), linestyle="--", label=f"Old mean: {old_vals.mean():.2f}")
plt.axvline(new_vals.mean(), linestyle="--", label=f"New mean: {new_vals.mean():.2f}")

plt.xlabel("Criterion value")
plt.ylabel("Density")
plt.title("Distribution of Criterion Values Across Seeds")
plt.legend()
plt.tight_layout()
plt.show()
